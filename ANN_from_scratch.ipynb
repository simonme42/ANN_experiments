# %% [markdown]
# <a href="https://colab.research.google.com/github/simonme42/ANN_experiments/blob/master/ANN_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ANN from scratch
#
# *   In this notebook, we implement an artificial neural network from scratch.
# *   All we need are a few standard python libraries
# *   At the end we´ll test our ANN implementation on image classification and regression tasks

# %%
import numpy as np
import scipy
import h5py
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # The functions that we need to implement a NN

# %%
def sigmoid(Z):
    """
    Implements the sigmoid activation in numpy
    
    Arguments:
    Z -- numpy array of any shape
    
    Returns:
    A -- output of sigmoid(z), same shape as Z
    cache -- returns Z as well, useful during backpropagation
    """
    
    A = 1/(1+np.exp(-Z))
    cache = Z
    
    return A, cache

def relu(Z):
    """
    Implement the RELU function.

    Arguments:
    Z -- Output of the linear layer, of any shape

    Returns:
    A -- Post-activation parameter, of the same shape as Z
    cache -- a python dictionary containing "A" ; stored for computing the backward pass efficiently
    """
    
    A = np.maximum(0,Z)
    
    assert(A.shape == Z.shape)
    
    cache = Z 
    return A, cache


def relu_backward(dA, cache):
    """
    Implement the backward propagation for a single RELU unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the cost with respect to Z
    """
    
    Z = cache
    dZ = np.array(dA, copy=True) # just converting dz to a correct object.
    
    # When z <= 0, you should set dz to 0 as well. 
    dZ[Z <= 0] = 0
    
    assert (dZ.shape == Z.shape)
    
    return dZ

def sigmoid_backward(dA, cache):
    """
    Implement the backward propagation for a single SIGMOID unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the cost with respect to Z
    """
    
    Z = cache
    
    s = 1/(1+np.exp(-Z))
    dZ = dA * s * (1-s)
    
    assert (dZ.shape == Z.shape)
    
    return dZ



def initialize_parameters_deep(layer_dims):
    """
    Arguments:
    layer_dims -- python array (list) containing the dimensions of each layer in our network
    
    Returns:
    parameters -- python dictionary containing your parameters "W1", "b1", ..., "WL", "bL":
                    Wl -- weight matrix of shape (layer_dims[l], layer_dims[l-1])
                    bl -- bias vector of shape (layer_dims[l], 1)
    """
    
    #np.random.seed(1)
    parameters = {}
    L = len(layer_dims)            # number of layers in the network

    for l in range(1, L):
        parameters['W' + str(l)] = np.random.randn(layer_dims[l], layer_dims[l-1]) / np.sqrt(layer_dims[l-1]) #*0.01
        parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))
        
        assert(parameters['W' + str(l)].shape == (layer_dims[l], layer_dims[l-1]))
        assert(parameters['b' + str(l)].shape == (layer_dims[l], 1))

        
    return parameters

def linear_forward(A, W, b):
    """
    Implement the linear part of a layer's forward propagation.

    Arguments:
    A -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)

    Returns:
    Z -- the input of the activation function, also called pre-activation parameter 
    cache -- a python dictionary containing "A", "W" and "b" ; stored for computing the backward pass efficiently
    """
    
    Z = np.dot(W,A)+b
    
    assert(Z.shape == (W.shape[0], A.shape[1]))
    cache = (A, W, b)
    
    return Z, cache

def linear_activation_forward(A_prev, W, b, activation):
    """
    Implement the forward propagation for the LINEAR->ACTIVATION layer

    Arguments:
    A_prev -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"

    Returns:
    A -- the output of the activation function, also called the post-activation value 
    cache -- a python dictionary containing "linear_cache" and "activation_cache";
             stored for computing the backward pass efficiently
    """
    
    if activation == "sigmoid":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = sigmoid(Z)
    
    elif activation == "relu":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = relu(Z)
    
    assert (A.shape == (W.shape[0], A_prev.shape[1]))
    cache = (linear_cache, activation_cache)

    return A, cache

def L_model_forward(X, parameters):
    """
    Implement forward propagation for the [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID computation
    
    Arguments:
    X -- data, numpy array of shape (input size, number of examples)
    parameters -- output of initialize_parameters_deep()
    
    Returns:
    AL -- last post-activation value
    caches -- list of caches containing:
                every cache of linear_relu_forward() (there are L-1 of them, indexed from 0 to L-2)
                the cache of linear_sigmoid_forward() (there is one, indexed L-1)
    """

    caches = []
    A = X
    L = len(parameters) // 2                  # number of layers in the neural network
    
    # Implement [LINEAR -> RELU]*(L-1). Add "cache" to the "caches" list.
    for l in range(1, L):
        A_prev = A 
        A, cache = linear_activation_forward(A_prev, parameters["W"+str(l)], parameters["b"+str(l)], activation="relu")
        caches.append(cache)
    
    # Implement LINEAR -> SIGMOID. Add "cache" to the "caches" list.
    AL, cache = linear_activation_forward(A, parameters["W"+str(L)], parameters["b"+str(L)], activation="sigmoid")
    caches.append(cache)
    
    assert(AL.shape == (1,X.shape[1]))
            
    return AL, caches

def compute_cost(AL, Y, loss="crossentropy"):
    """
    Implement the cost function

    Arguments:
    AL -- probability vector corresponding to your label predictions, shape (1, number of examples)
    Y -- true "label" vector (for example: containing 0 if non-cat, 1 if cat), shape (1, number of examples)

    Returns:
    cost -- cross-entropy or mse cost
    """
    
    m = Y.shape[1]

    # Compute loss from aL and y.
    if loss == "crossentropy":
      cost = (1./m) * (-np.dot(Y,np.log(AL).T) - np.dot(1-Y, np.log(1-AL).T))
    
    elif loss == "mse":
      cost = (1./m) * (np.sum((AL-Y)**2,axis=1, keepdims=True))
    
    cost = np.squeeze(cost)      # To make sure the cost's shape is what we expect (e.g. this turns [[17]] into 17).
    assert(cost.shape == ())
    
    return cost

def linear_backward(dZ, cache):
    """
    Implement the linear portion of backward propagation for a single layer (layer l)

    Arguments:
    dZ -- Gradient of the cost with respect to the linear output (of current layer l)
    cache -- tuple of values (A_prev, W, b) coming from the forward propagation in the current layer

    Returns:
    dA_prev -- Gradient of the cost with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the cost with respect to W (current layer l), same shape as W
    db -- Gradient of the cost with respect to b (current layer l), same shape as b
    """
    A_prev, W, b = cache
    m = A_prev.shape[1]

    dW = 1./m * np.dot(dZ,A_prev.T)
    db = 1./m * np.sum(dZ, axis = 1, keepdims = True)
    dA_prev = np.dot(W.T,dZ)
    
    assert (dA_prev.shape == A_prev.shape)
    assert (dW.shape == W.shape)
    assert (db.shape == b.shape)
    
    return dA_prev, dW, db

def linear_activation_backward(dA, cache, activation):
    """
    Implement the backward propagation for the LINEAR->ACTIVATION layer.
    
    Arguments:
    dA -- post-activation gradient for current layer l 
    cache -- tuple of values (linear_cache, activation_cache) we store for computing backward propagation efficiently
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"
    
    Returns:
    dA_prev -- Gradient of the cost with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the cost with respect to W (current layer l), same shape as W
    db -- Gradient of the cost with respect to b (current layer l), same shape as b
    """
    linear_cache, activation_cache = cache
    
    if activation == "relu":
        dZ = relu_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
        
    elif activation == "sigmoid":
        dZ = sigmoid_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
    
    return dA_prev, dW, db

def L_model_backward(AL, Y, caches, loss="crossentropy"):
    """
    Implement the backward propagation for the [LINEAR->RELU] * (L-1) -> LINEAR -> SIGMOID group
    
    Arguments:
    AL -- probability vector, output of the forward propagation (L_model_forward())
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat)
    caches -- list of caches containing:
                every cache of linear_activation_forward() with "relu" (there are (L-1) or them, indexes from 0 to L-2)
                the cache of linear_activation_forward() with "sigmoid" (there is one, index L-1)
    
    Returns:
    grads -- A dictionary with the gradients
             grads["dA" + str(l)] = ... 
             grads["dW" + str(l)] = ...
             grads["db" + str(l)] = ... 
    """
    grads = {}
    L = len(caches) # the number of layers
    m = AL.shape[1]
    Y = Y.reshape(AL.shape) # after this line, Y is the same shape as AL
    
    # Initializing the backpropagation

    if loss == "crossentropy":
      dAL = - (np.divide(Y, AL) - np.divide(1 - Y, 1 - AL))
    
    elif loss == "mse":
      dAL = 2*(AL-Y)
    
    # Lth layer (SIGMOID -> LINEAR) gradients. Inputs: "AL, Y, caches". Outputs: "grads["dAL"], grads["dWL"], grads["dbL"]
    current_cache = caches[L-1]
    grads["dA" + str(L-1)], grads["dW" + str(L)], grads["db" + str(L)] = linear_activation_backward(dAL, current_cache, activation = "sigmoid")
    
    for l in reversed(range(L-1)):
        # lth layer: (RELU -> LINEAR) gradients.
        current_cache = caches[l]
        dA_prev_temp, dW_temp, db_temp = linear_activation_backward(grads["dA" + str(l + 1)], current_cache, activation = "relu")
        grads["dA" + str(l)] = dA_prev_temp
        grads["dW" + str(l + 1)] = dW_temp
        grads["db" + str(l + 1)] = db_temp

    return grads

def update_parameters(parameters, grads, learning_rate):
    """
    Update parameters using gradient descent
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    grads -- python dictionary containing your gradients, output of L_model_backward
    
    Returns:
    parameters -- python dictionary containing your updated parameters 
                  parameters["W" + str(l)] = ... 
                  parameters["b" + str(l)] = ...
    """
    
    L = len(parameters) // 2 # number of layers in the neural network

    # Update rule for each parameter. Use a for loop.
    for l in range(L):
        parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * grads["dW" + str(l+1)]
        parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * grads["db" + str(l+1)]
        
    return parameters

def predict(X, y, parameters, loss="crossentropy"):
    """
    This function is used to predict the results of a  L-layer neural network.
    
    Arguments:
    X -- data set of examples you would like to label
    parameters -- parameters of the trained model
    
    Returns:
    p -- predictions for the given dataset X
    """
    m = X.shape[1]
    n = len(parameters) // 2 # number of layers in the neural network

    if loss == "crossentropy":
     
      p = np.zeros((1,m))
        
      # Forward propagation
      probas, caches = L_model_forward(X, parameters)
        
      # convert probas to 0/1 predictions
      for i in range(0, probas.shape[1]):
          if probas[0,i] > 0.5:
            p[0,i] = 1
          else:
            p[0,i] = 0
      
      print("Accuracy: "  + str(np.sum((p == y)/m)))

    elif loss == "mse":

      p, caches = L_model_forward(X, parameters)

      print("Accuracy: "  + str((1/m)*np.sum(p-y)**2))
    
    #print results
    #print ("predictions: " + str(p))
    #print ("true labels: " + str(y))
    
    return p

def print_mislabeled_images(classes, X, y, p):
    """
    Plots images where predictions and truth were different.
    X -- dataset
    y -- true labels
    p -- predictions
    """
    a = p + y
    mislabeled_indices = np.asarray(np.where(a == 1))
    plt.rcParams['figure.figsize'] = (40.0, 40.0) # set default size of plots
    num_images = len(mislabeled_indices[0])
    for i in range(num_images):
        index = mislabeled_indices[1][i]
        
        plt.subplot(2, num_images, i + 1)
        plt.imshow(X[:,index].reshape(64,64,3), interpolation='nearest')
        plt.axis('off')
        plt.title("Prediction: " + classes[int(p[0,index])].decode("utf-8") + " \n Class: " + classes[y[0,index]].decode("utf-8"))

def train_model(X, Y, layers_dims, learning_rate = 0.0075, num_iterations = 3000, print_cost=False, loss="crossentropy"):
    """
    Implements a L-layer neural network: [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID.
    
    Arguments:
    X -- data, numpy array of shape (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if cat, 1 if non-cat), of shape (1, number of examples)
    layers_dims -- list containing the input size and each layer size, of length (number of layers + 1).
    learning_rate -- learning rate of the gradient descent update rule
    num_iterations -- number of iterations of the optimization loop
    print_cost -- if True, it prints the cost every 100 steps
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """

    np.random.seed(1)
    costs = []                         # keep track of cost
    
    parameters = initialize_parameters_deep(layers_dims)
    
    # Loop (gradient descent)
    for i in range(0, num_iterations):

        AL, caches = L_model_forward(X, parameters)
        
        # Compute cost.
        cost = compute_cost(AL, Y, loss=loss)
    
        # Backward propagation.
        grads = L_model_backward(AL, Y, caches, loss=loss)
 
        # Update parameters.
        parameters = update_parameters(parameters, grads, learning_rate)
                
        # Print the cost every 100 training example
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
        if print_cost and i % 100 == 0:
            costs.append(cost)
            
    # plot the cost
    plt.plot(np.squeeze(costs))
    plt.ylabel('cost')
    plt.xlabel('iterations (per hundreds)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    
    return parameters

# %% [markdown]
# # Now we train and test our NN on binary image classification using cat vs noncat

# %%
# !git clone https://github.com/simonme42/ANN_experiments.git
# Out:
# Cloning into 'ANN_experiments'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 66 (delta 30), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (66/66), done.

# %%
def load_data():
  train_dataset = h5py.File("ANN_experiments/datasets/train_catvnoncat.h5", "r")
  train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
  train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

  test_dataset = h5py.File("ANN_experiments/datasets/test_catvnoncat.h5", "r")
  test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
  test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

  classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
  train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
  test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
  return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1).T   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1).T

# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.
test_x = test_x_flatten/255.

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
# Out:
# train_x's shape: (12288, 209)
# test_x's shape: (12288, 50)

# %%
layers_dims = [train_x.shape[0], 20, 7, 5, 1]

parameters = train_model(train_x, train_y, layers_dims, num_iterations = 2000, print_cost = True, loss="crossentropy")
# Out:
# Cost after iteration 0: 0.771749
# Cost after iteration 100: 0.672053
# Cost after iteration 200: 0.648263
# Cost after iteration 300: 0.611507
# Cost after iteration 400: 0.567047
# Cost after iteration 500: 0.540138
# Cost after iteration 600: 0.527930
# Cost after iteration 700: 0.465477
# Cost after iteration 800: 0.369126
# Cost after iteration 900: 0.391747
# Cost after iteration 1000: 0.315187
# Cost after iteration 1100: 0.272700
# Cost after iteration 1200: 0.237419
# Cost after iteration 1300: 0.199601
# Cost after iteration 1400: 0.189263
# Cost after iteration 1500: 0.161189
# Cost after iteration 1600: 0.148214
# Cost after iteration 1700: 0.137775
# Cost after iteration 1800: 0.129740
# Cost after iteration 1900: 0.121225

# %%
pred_train = predict(train_x, train_y, parameters)
pred_test = predict(test_x, test_y, parameters)
# Out:
# Accuracy: 0.9808612440191385
# Accuracy: 0.8

# %%
print_mislabeled_images(classes, test_x, test_y, pred_test)

# %% [markdown]
# ## Now we use our NN implementation for a Regression task (adding 2 numbers)

# %%
def create_mse_data(low, high, m, train_test_split=0.2):

  mse_X = np.random.randint(low,high=high, size=(2,m))
  mse_X_scaled = mse_X/(high)

  mse_Y = (mse_X[0,:]+mse_X[1,:]).reshape(1,mse_X.shape[1])
  mse_Y_scaled = mse_Y/(high*2)

  mse_X_train = mse_X_scaled[:,0:int(m*train_test_split)]
  mse_X_test = mse_X_scaled[:,int(m*train_test_split):]
  mse_Y_train = mse_Y_scaled[:,0:int(m*train_test_split)]
  mse_Y_test = mse_Y_scaled[:,int(m*train_test_split):]

  return (mse_X_train,mse_X_test,mse_Y_train,mse_Y_test)


(mse_X_train,mse_X_test,mse_Y_train,mse_Y_test) = create_mse_data(0,50,10000)

layers_dims_mse = [mse_X_train.shape[0],5,4,1]

# %%
parameters = train_model(mse_X_train, mse_Y_train, layers_dims_mse, num_iterations = 50000, print_cost = True, loss="mse", learning_rate = 0.01)
# Out:
# Cost after iteration 0: 0.042018
# Cost after iteration 100: 0.041773
# Cost after iteration 200: 0.041530
# Cost after iteration 300: 0.041269
# Cost after iteration 400: 0.040992
# Cost after iteration 500: 0.040693
# Cost after iteration 600: 0.040385
# Cost after iteration 700: 0.040100
# Cost after iteration 800: 0.039863
# Cost after iteration 900: 0.039662
# Cost after iteration 1000: 0.039487
# Cost after iteration 1100: 0.039327
# Cost after iteration 1200: 0.039172
# Cost after iteration 1300: 0.039022
# Cost after iteration 1400: 0.038880
# Cost after iteration 1500: 0.038741
# Cost after iteration 1600: 0.038605
# Cost after iteration 1700: 0.038470
# Cost after iteration 1800: 0.038335
# Cost after iteration 1900: 0.038199
# Cost after iteration 2000: 0.038062
# Cost after iteration 2100: 0.037925
# Cost after iteration 2200: 0.037787
# Cost after iteration 2300: 0.037648
# Cost after iteration 2400: 0.037508
# Cost after iteration 2500: 0.037372
# Cost after iteration 2600: 0.037233
# Cost after iteration 2700: 0.037093
# Cost after iteration 2800: 0.036952
# Cost after iteration 2900: 0.036809
# Cost after iteration 3000: 0.036663
# Cost after iteration 3100: 0.036518
# Cost after iteration 3200: 0.036370
# Cost after iteration 3300: 0.036219
# Cost after iteration 3400: 0.036067
# Cost after iteration 3500: 0.035914
# Cost after iteration 3600: 0.035758
# Cost after iteration 3700: 0.035600
# Cost after iteration 3800: 0.035438
# Cost after iteration 3900: 0.035272
# Cost after iteration 4000: 0.035101
# Cost after iteration 4100: 0.034928
# Cost after iteration 4200: 0.034752
# Cost after iteration 4300: 0.034571
# Cost after iteration 4400: 0.034385
# Cost after iteration 4500: 0.034194
# Cost after iteration 4600: 0.033998
# Cost after iteration 4700: 0.033795
# Cost after iteration 4800: 0.033586
# Cost after iteration 4900: 0.033372
# Cost after iteration 5000: 0.033152
# Cost after iteration 5100: 0.032926
# Cost after iteration 5200: 0.032694
# Cost after iteration 5300: 0.032457
# Cost after iteration 5400: 0.032214
# Cost after iteration 5500: 0.031964
# Cost after iteration 5600: 0.031707
# Cost after iteration 5700: 0.031446
# Cost after iteration 5800: 0.031178
# Cost after iteration 5900: 0.030903
# Cost after iteration 6000: 0.030621
# Cost after iteration 6100: 0.030332
# Cost after iteration 6200: 0.030035
# Cost after iteration 6300: 0.029731
# Cost after iteration 6400: 0.029419
# Cost after iteration 6500: 0.029100
# Cost after iteration 6600: 0.028774
# Cost after iteration 6700: 0.028442
# Cost after iteration 6800: 0.028101
# Cost after iteration 6900: 0.027755
# Cost after iteration 7000: 0.027402
# Cost after iteration 7100: 0.027042
# Cost after iteration 7200: 0.026676
# Cost after iteration 7300: 0.026303
# Cost after iteration 7400: 0.025923
# Cost after iteration 7500: 0.025536
# Cost after iteration 7600: 0.025143
# Cost after iteration 7700: 0.024743
# Cost after iteration 7800: 0.024337
# Cost after iteration 7900: 0.023925
# Cost after iteration 8000: 0.023508
# Cost after iteration 8100: 0.023083
# Cost after iteration 8200: 0.022654
# Cost after iteration 8300: 0.022220
# Cost after iteration 8400: 0.021781
# Cost after iteration 8500: 0.021339
# Cost after iteration 8600: 0.020894
# Cost after iteration 8700: 0.020446
# Cost after iteration 8800: 0.019997
# Cost after iteration 8900: 0.019547
# Cost after iteration 9000: 0.019093
# Cost after iteration 9100: 0.018639
# Cost after iteration 9200: 0.018186
# Cost after iteration 9300: 0.017732
# Cost after iteration 9400: 0.017279
# Cost after iteration 9500: 0.016828
# Cost after iteration 9600: 0.016380
# Cost after iteration 9700: 0.015935
# Cost after iteration 9800: 0.015493
# Cost after iteration 9900: 0.015056
# Cost after iteration 10000: 0.014624
# Cost after iteration 10100: 0.014198
# Cost after iteration 10200: 0.013778
# Cost after iteration 10300: 0.013363
# Cost after iteration 10400: 0.012956
# Cost after iteration 10500: 0.012556
# Cost after iteration 10600: 0.012163
# Cost after iteration 10700: 0.011778
# Cost after iteration 10800: 0.011401
# Cost after iteration 10900: 0.011032
# Cost after iteration 11000: 0.010672
# Cost after iteration 11100: 0.010322
# Cost after iteration 11200: 0.009981
# Cost after iteration 11300: 0.009650
# Cost after iteration 11400: 0.009330
# Cost after iteration 11500: 0.009020
# Cost after iteration 11600: 0.008719
# Cost after iteration 11700: 0.008429
# Cost after iteration 11800: 0.008147
# Cost after iteration 11900: 0.007875
# Cost after iteration 12000: 0.007613
# Cost after iteration 12100: 0.007360
# Cost after iteration 12200: 0.007117
# Cost after iteration 12300: 0.006882
# Cost after iteration 12400: 0.006657
# Cost after iteration 12500: 0.006440
# Cost after iteration 12600: 0.006232
# Cost after iteration 12700: 0.006032
# Cost after iteration 12800: 0.005840
# Cost after iteration 12900: 0.005656
# Cost after iteration 13000: 0.005480
# Cost after iteration 13100: 0.005311
# Cost after iteration 13200: 0.005149
# Cost after iteration 13300: 0.004994
# Cost after iteration 13400: 0.004846
# Cost after iteration 13500: 0.004704
# Cost after iteration 13600: 0.004568
# Cost after iteration 13700: 0.004438
# Cost after iteration 13800: 0.004313
# Cost after iteration 13900: 0.004194
# Cost after iteration 14000: 0.004080
# Cost after iteration 14100: 0.003970
# Cost after iteration 14200: 0.003866
# Cost after iteration 14300: 0.003766
# Cost after iteration 14400: 0.003671
# Cost after iteration 14500: 0.003579
# Cost after iteration 14600: 0.003492
# Cost after iteration 14700: 0.003408
# Cost after iteration 14800: 0.003328
# Cost after iteration 14900: 0.003251
# Cost after iteration 15000: 0.003177
# Cost after iteration 15100: 0.003107
# Cost after iteration 15200: 0.003039
# Cost after iteration 15300: 0.002975
# Cost after iteration 15400: 0.002912
# Cost after iteration 15500: 0.002853
# Cost after iteration 15600: 0.002795
# Cost after iteration 15700: 0.002740
# Cost after iteration 15800: 0.002688
# Cost after iteration 15900: 0.002637
# Cost after iteration 16000: 0.002588
# Cost after iteration 16100: 0.002541
# Cost after iteration 16200: 0.002496
# Cost after iteration 16300: 0.002453
# Cost after iteration 16400: 0.002411
# Cost after iteration 16500: 0.002371
# Cost after iteration 16600: 0.002332
# Cost after iteration 16700: 0.002294
# Cost after iteration 16800: 0.002258
# Cost after iteration 16900: 0.002224
# Cost after iteration 17000: 0.002190
# Cost after iteration 17100: 0.002157
# Cost after iteration 17200: 0.002126
# Cost after iteration 17300: 0.002095
# Cost after iteration 17400: 0.002066
# Cost after iteration 17500: 0.002037
# Cost after iteration 17600: 0.002010
# Cost after iteration 17700: 0.001983
# Cost after iteration 17800: 0.001957
# Cost after iteration 17900: 0.001932
# Cost after iteration 18000: 0.001907
# Cost after iteration 18100: 0.001883
# Cost after iteration 18200: 0.001860
# Cost after iteration 18300: 0.001838
# Cost after iteration 18400: 0.001816
# Cost after iteration 18500: 0.001795
# Cost after iteration 18600: 0.001774
# Cost after iteration 18700: 0.001754
# Cost after iteration 18800: 0.001734
# Cost after iteration 18900: 0.001715
# Cost after iteration 19000: 0.001697
# Cost after iteration 19100: 0.001678
# Cost after iteration 19200: 0.001661
# Cost after iteration 19300: 0.001643
# Cost after iteration 19400: 0.001626
# Cost after iteration 19500: 0.001610
# Cost after iteration 19600: 0.001594
# Cost after iteration 19700: 0.001578
# Cost after iteration 19800: 0.001562
# Cost after iteration 19900: 0.001547
# Cost after iteration 20000: 0.001532
# Cost after iteration 20100: 0.001518
# Cost after iteration 20200: 0.001504
# Cost after iteration 20300: 0.001490
# Cost after iteration 20400: 0.001476
# Cost after iteration 20500: 0.001463
# Cost after iteration 20600: 0.001450
# Cost after iteration 20700: 0.001437
# Cost after iteration 20800: 0.001424
# Cost after iteration 20900: 0.001412
# Cost after iteration 21000: 0.001400
# Cost after iteration 21100: 0.001388
# Cost after iteration 21200: 0.001376
# Cost after iteration 21300: 0.001365
# Cost after iteration 21400: 0.001353
# Cost after iteration 21500: 0.001342
# Cost after iteration 21600: 0.001331
# Cost after iteration 21700: 0.001321
# Cost after iteration 21800: 0.001310
# Cost after iteration 21900: 0.001300
# Cost after iteration 22000: 0.001290
# Cost after iteration 22100: 0.001280
# Cost after iteration 22200: 0.001270
# Cost after iteration 22300: 0.001260
# Cost after iteration 22400: 0.001251
# Cost after iteration 22500: 0.001241
# Cost after iteration 22600: 0.001232
# Cost after iteration 22700: 0.001223
# Cost after iteration 22800: 0.001214
# Cost after iteration 22900: 0.001205
# Cost after iteration 23000: 0.001197
# Cost after iteration 23100: 0.001188
# Cost after iteration 23200: 0.001180
# Cost after iteration 23300: 0.001172
# Cost after iteration 23400: 0.001163
# Cost after iteration 23500: 0.001155
# Cost after iteration 23600: 0.001148
# Cost after iteration 23700: 0.001140
# Cost after iteration 23800: 0.001132
# Cost after iteration 23900: 0.001125
# Cost after iteration 24000: 0.001117
# Cost after iteration 24100: 0.001110
# Cost after iteration 24200: 0.001103
# Cost after iteration 24300: 0.001095
# Cost after iteration 24400: 0.001088
# Cost after iteration 24500: 0.001082
# Cost after iteration 24600: 0.001075
# Cost after iteration 24700: 0.001068
# Cost after iteration 24800: 0.001061
# Cost after iteration 24900: 0.001055
# Cost after iteration 25000: 0.001048
# Cost after iteration 25100: 0.001042
# Cost after iteration 25200: 0.001036
# Cost after iteration 25300: 0.001029
# Cost after iteration 25400: 0.001023
# Cost after iteration 25500: 0.001017
# Cost after iteration 25600: 0.001011
# Cost after iteration 25700: 0.001005
# Cost after iteration 25800: 0.001000
# Cost after iteration 25900: 0.000994
# Cost after iteration 26000: 0.000988
# Cost after iteration 26100: 0.000982
# Cost after iteration 26200: 0.000977
# Cost after iteration 26300: 0.000971
# Cost after iteration 26400: 0.000966
# Cost after iteration 26500: 0.000961
# Cost after iteration 26600: 0.000955
# Cost after iteration 26700: 0.000950
# Cost after iteration 26800: 0.000945
# Cost after iteration 26900: 0.000940
# Cost after iteration 27000: 0.000935
# Cost after iteration 27100: 0.000930
# Cost after iteration 27200: 0.000925
# Cost after iteration 27300: 0.000920
# Cost after iteration 27400: 0.000915
# Cost after iteration 27500: 0.000910
# Cost after iteration 27600: 0.000906
# Cost after iteration 27700: 0.000901
# Cost after iteration 27800: 0.000896
# Cost after iteration 27900: 0.000892
# Cost after iteration 28000: 0.000887
# Cost after iteration 28100: 0.000883
# Cost after iteration 28200: 0.000878
# Cost after iteration 28300: 0.000874
# Cost after iteration 28400: 0.000870
# Cost after iteration 28500: 0.000866
# Cost after iteration 28600: 0.000861
# Cost after iteration 28700: 0.000857
# Cost after iteration 28800: 0.000853
# Cost after iteration 28900: 0.000849
# Cost after iteration 29000: 0.000845
# Cost after iteration 29100: 0.000841
# Cost after iteration 29200: 0.000837
# Cost after iteration 29300: 0.000833
# Cost after iteration 29400: 0.000829
# Cost after iteration 29500: 0.000825
# Cost after iteration 29600: 0.000821
# Cost after iteration 29700: 0.000817
# Cost after iteration 29800: 0.000814
# Cost after iteration 29900: 0.000810
# Cost after iteration 30000: 0.000806
# Cost after iteration 30100: 0.000803
# Cost after iteration 30200: 0.000799
# Cost after iteration 30300: 0.000796
# Cost after iteration 30400: 0.000792
# Cost after iteration 30500: 0.000789
# Cost after iteration 30600: 0.000785
# Cost after iteration 30700: 0.000782
# Cost after iteration 30800: 0.000778
# Cost after iteration 30900: 0.000775
# Cost after iteration 31000: 0.000771
# Cost after iteration 31100: 0.000768
# Cost after iteration 31200: 0.000765
# Cost after iteration 31300: 0.000762
# Cost after iteration 31400: 0.000758
# Cost after iteration 31500: 0.000755
# Cost after iteration 31600: 0.000752
# Cost after iteration 31700: 0.000749
# Cost after iteration 31800: 0.000746
# Cost after iteration 31900: 0.000743
# Cost after iteration 32000: 0.000740
# Cost after iteration 32100: 0.000737
# Cost after iteration 32200: 0.000734
# Cost after iteration 32300: 0.000731
# Cost after iteration 32400: 0.000728
# Cost after iteration 32500: 0.000725
# Cost after iteration 32600: 0.000722
# Cost after iteration 32700: 0.000719
# Cost after iteration 32800: 0.000716
# Cost after iteration 32900: 0.000713
# Cost after iteration 33000: 0.000711
# Cost after iteration 33100: 0.000708
# Cost after iteration 33200: 0.000705
# Cost after iteration 33300: 0.000702
# Cost after iteration 33400: 0.000700
# Cost after iteration 33500: 0.000697
# Cost after iteration 33600: 0.000694
# Cost after iteration 33700: 0.000691
# Cost after iteration 33800: 0.000689
# Cost after iteration 33900: 0.000686
# Cost after iteration 34000: 0.000684
# Cost after iteration 34100: 0.000681
# Cost after iteration 34200: 0.000679
# Cost after iteration 34300: 0.000676
# Cost after iteration 34400: 0.000674
# Cost after iteration 34500: 0.000671
# Cost after iteration 34600: 0.000669
# Cost after iteration 34700: 0.000666
# Cost after iteration 34800: 0.000664
# Cost after iteration 34900: 0.000661
# Cost after iteration 35000: 0.000659
# Cost after iteration 35100: 0.000657
# Cost after iteration 35200: 0.000654
# Cost after iteration 35300: 0.000652
# Cost after iteration 35400: 0.000650
# Cost after iteration 35500: 0.000647
# Cost after iteration 35600: 0.000645
# Cost after iteration 35700: 0.000643
# Cost after iteration 35800: 0.000641
# Cost after iteration 35900: 0.000638
# Cost after iteration 36000: 0.000636
# Cost after iteration 36100: 0.000634
# Cost after iteration 36200: 0.000632
# Cost after iteration 36300: 0.000630
# Cost after iteration 36400: 0.000628
# Cost after iteration 36500: 0.000626
# Cost after iteration 36600: 0.000623
# Cost after iteration 36700: 0.000621
# Cost after iteration 36800: 0.000619
# Cost after iteration 36900: 0.000617
# Cost after iteration 37000: 0.000615
# Cost after iteration 37100: 0.000613
# Cost after iteration 37200: 0.000611
# Cost after iteration 37300: 0.000609
# Cost after iteration 37400: 0.000607
# Cost after iteration 37500: 0.000605
# Cost after iteration 37600: 0.000603
# Cost after iteration 37700: 0.000601
# Cost after iteration 37800: 0.000599
# Cost after iteration 37900: 0.000597
# Cost after iteration 38000: 0.000596
# Cost after iteration 38100: 0.000594
# Cost after iteration 38200: 0.000592
# Cost after iteration 38300: 0.000590
# Cost after iteration 38400: 0.000588
# Cost after iteration 38500: 0.000586
# Cost after iteration 38600: 0.000585
# Cost after iteration 38700: 0.000583
# Cost after iteration 38800: 0.000581
# Cost after iteration 38900: 0.000579
# Cost after iteration 39000: 0.000577
# Cost after iteration 39100: 0.000576
# Cost after iteration 39200: 0.000574
# Cost after iteration 39300: 0.000572
# Cost after iteration 39400: 0.000571
# Cost after iteration 39500: 0.000569
# Cost after iteration 39600: 0.000567
# Cost after iteration 39700: 0.000566
# Cost after iteration 39800: 0.000564
# Cost after iteration 39900: 0.000562
# Cost after iteration 40000: 0.000561
# Cost after iteration 40100: 0.000559
# Cost after iteration 40200: 0.000558
# Cost after iteration 40300: 0.000556
# Cost after iteration 40400: 0.000554
# Cost after iteration 40500: 0.000553
# Cost after iteration 40600: 0.000551
# Cost after iteration 40700: 0.000550
# Cost after iteration 40800: 0.000548
# Cost after iteration 40900: 0.000547
# Cost after iteration 41000: 0.000545
# Cost after iteration 41100: 0.000544
# Cost after iteration 41200: 0.000542
# Cost after iteration 41300: 0.000541
# Cost after iteration 41400: 0.000539
# Cost after iteration 41500: 0.000538
# Cost after iteration 41600: 0.000536
# Cost after iteration 41700: 0.000535
# Cost after iteration 41800: 0.000534
# Cost after iteration 41900: 0.000532
# Cost after iteration 42000: 0.000531
# Cost after iteration 42100: 0.000529
# Cost after iteration 42200: 0.000528
# Cost after iteration 42300: 0.000527
# Cost after iteration 42400: 0.000525
# Cost after iteration 42500: 0.000524
# Cost after iteration 42600: 0.000523
# Cost after iteration 42700: 0.000521
# Cost after iteration 42800: 0.000520
# Cost after iteration 42900: 0.000519
# Cost after iteration 43000: 0.000517
# Cost after iteration 43100: 0.000516
# Cost after iteration 43200: 0.000515
# Cost after iteration 43300: 0.000514
# Cost after iteration 43400: 0.000512
# Cost after iteration 43500: 0.000511
# Cost after iteration 43600: 0.000510
# Cost after iteration 43700: 0.000509
# Cost after iteration 43800: 0.000507
# Cost after iteration 43900: 0.000506
# Cost after iteration 44000: 0.000505
# Cost after iteration 44100: 0.000504
# Cost after iteration 44200: 0.000502
# Cost after iteration 44300: 0.000501
# Cost after iteration 44400: 0.000500
# Cost after iteration 44500: 0.000499
# Cost after iteration 44600: 0.000498
# Cost after iteration 44700: 0.000497
# Cost after iteration 44800: 0.000495
# Cost after iteration 44900: 0.000494
# Cost after iteration 45000: 0.000493
# Cost after iteration 45100: 0.000492
# Cost after iteration 45200: 0.000491
# Cost after iteration 45300: 0.000490
# Cost after iteration 45400: 0.000489
# Cost after iteration 45500: 0.000488
# Cost after iteration 45600: 0.000487
# Cost after iteration 45700: 0.000485
# Cost after iteration 45800: 0.000484
# Cost after iteration 45900: 0.000483
# Cost after iteration 46000: 0.000482
# Cost after iteration 46100: 0.000481
# Cost after iteration 46200: 0.000480
# Cost after iteration 46300: 0.000479
# Cost after iteration 46400: 0.000478
# Cost after iteration 46500: 0.000477
# Cost after iteration 46600: 0.000476
# Cost after iteration 46700: 0.000475
# Cost after iteration 46800: 0.000474
# Cost after iteration 46900: 0.000473
# Cost after iteration 47000: 0.000472
# Cost after iteration 47100: 0.000471
# Cost after iteration 47200: 0.000470
# Cost after iteration 47300: 0.000469
# Cost after iteration 47400: 0.000468
# Cost after iteration 47500: 0.000467
# Cost after iteration 47600: 0.000466
# Cost after iteration 47700: 0.000465
# Cost after iteration 47800: 0.000464
# Cost after iteration 47900: 0.000463
# Cost after iteration 48000: 0.000462
# Cost after iteration 48100: 0.000461
# Cost after iteration 48200: 0.000460
# Cost after iteration 48300: 0.000459
# Cost after iteration 48400: 0.000458
# Cost after iteration 48500: 0.000458
# Cost after iteration 48600: 0.000457
# Cost after iteration 48700: 0.000456
# Cost after iteration 48800: 0.000455
# Cost after iteration 48900: 0.000454
# Cost after iteration 49000: 0.000453
# Cost after iteration 49100: 0.000452
# Cost after iteration 49200: 0.000451
# Cost after iteration 49300: 0.000450
# Cost after iteration 49400: 0.000450
# Cost after iteration 49500: 0.000449
# Cost after iteration 49600: 0.000448
# Cost after iteration 49700: 0.000447
# Cost after iteration 49800: 0.000446
# Cost after iteration 49900: 0.000445

# %%
pred_train = predict(mse_X_train, mse_Y_train, parameters, loss="mse")

p, caches = L_model_forward(mse_X_train, parameters)
print((p*100-mse_Y_train*100)[:,0:50])
# Out:
# Accuracy: 0.0046279504339635635
# [[  0.17438148   1.12185665  -5.67282597  -1.08841996  -0.41604477
#    -0.54579197  -0.77033785   1.40655962 -11.67282597   0.57668381
#    -1.2092203   -0.79464147  -1.66657928  -3.00521535   0.11099038
#    -1.28292093  -1.25405878  -0.6959312    0.86554421  -1.16230975
#    -0.03681477  -0.34431414  -0.59437027  -0.86585791  -1.16815463
#    -1.06546662  -0.64617014   0.5633652    3.57865678   0.96938133
#     0.11801828   0.15514518   1.09406192  -0.50686607  -0.51169509
#     0.5395801   -0.96308083  -2.73289293   1.75481611  -5.67282597
#     0.86027224   0.93049932  -0.26655571  -0.77529992  -0.94614971
#     0.97123819  -0.08435496  -0.82529554  -0.75156418   0.9105398 ]]

# %%
pred_test = predict(mse_X_test, mse_Y_test, parameters, loss="mse")

p, caches = L_model_forward(mse_X_test, parameters)

print((mse_Y_test*100)[:,0:10])
print((p*100)[:,0:10])
print((p*100-mse_Y_test*100)[:,0:50])
# Out:
# Accuracy: 0.022605998903123287
# [[14. 69. 47. 63. 80. 41. 49. 51. 30. 93.]]
# [[16.78460846 69.80230023 46.66657826 63.99438923 79.07662118 39.66212661
#   48.960359   51.01583242 29.08770855 81.32717403]]
# [[ 2.78460846e+00  8.02300230e-01 -3.33421737e-01  9.94389234e-01
#   -9.23378821e-01 -1.33787339e+00 -3.96409966e-02  1.58324180e-02
#   -9.12291449e-01 -1.16728260e+01 -7.67525612e+00  7.71019344e-01
#   -8.27070513e-02 -9.93005756e-01  1.46070273e-01  8.95230288e-01
#    1.02786602e+00  2.33437937e-01  9.80461718e-01  9.27599800e-01
#   -9.67475897e+00  3.58087604e+00  4.44848221e+00  1.79070226e-01
#    7.81200862e-01  4.87738760e-01  4.53084237e-01 -1.04413201e+00
#   -1.58219982e-01 -2.02189793e+00  8.72074646e-01  7.07872592e-02
#    7.33851152e-01  8.67605414e-01  6.58266797e-01  9.35489891e-01
#    7.86016502e-03  6.75836273e-01 -2.02189793e+00  6.29574957e-01
#   -9.23378821e-01  1.57431670e-01 -6.97657631e-01 -9.04133829e-01
#   -5.27931161e-01  2.38180785e-02 -1.62341686e+00  9.52662476e-01
#    2.43450938e-01 -1.00652572e+00]]

# %%
p*100
