# %% [markdown]
# <a href="https://colab.research.google.com/github/simonme42/ANN_experiments/blob/master/ANN_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ANN from scratch
#
# *   In this notebook, we implement an artificial neural network from scratch.
# *   All we need are a few standard python libraries
# *   At the end we´ll test our ANN implementation on image classification and regression tasks

# %%
import numpy as np
import scipy
import h5py
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # The functions that we need to implement a NN

# %%
def sigmoid(Z):
    """
    Implements the sigmoid activation in numpy
    
    Arguments:
    Z -- numpy array of any shape
    
    Returns:
    A -- output of sigmoid(z), same shape as Z
    cache -- returns Z as well, useful during backpropagation
    """
    
    A = 1/(1+np.exp(-Z))
    cache = Z
    
    return A, cache

def relu(Z):
    """
    Implement the RELU function.

    Arguments:
    Z -- Output of the linear layer, of any shape

    Returns:
    A -- Post-activation parameter, of the same shape as Z
    cache -- a python dictionary containing "A" ; stored for computing the backward pass efficiently
    """
    
    A = np.maximum(0,Z)
    
    assert(A.shape == Z.shape)
    
    cache = Z 
    return A, cache


def relu_backward(dA, cache):
    """
    Implement the backward propagation for a single RELU unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the cost with respect to Z
    """
    
    Z = cache
    dZ = np.array(dA, copy=True) # just converting dz to a correct object.
    
    # When z <= 0, you should set dz to 0 as well. 
    dZ[Z <= 0] = 0
    
    assert (dZ.shape == Z.shape)
    
    return dZ

def sigmoid_backward(dA, cache):
    """
    Implement the backward propagation for a single SIGMOID unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the cost with respect to Z
    """
    
    Z = cache
    
    s = 1/(1+np.exp(-Z))
    dZ = dA * s * (1-s)
    
    assert (dZ.shape == Z.shape)
    
    return dZ



def initialize_parameters_deep(layer_dims):
    """
    Arguments:
    layer_dims -- python array (list) containing the dimensions of each layer in our network
    
    Returns:
    parameters -- python dictionary containing your parameters "W1", "b1", ..., "WL", "bL":
                    Wl -- weight matrix of shape (layer_dims[l], layer_dims[l-1])
                    bl -- bias vector of shape (layer_dims[l], 1)
    """
    
    #np.random.seed(1)
    parameters = {}
    L = len(layer_dims)            # number of layers in the network

    for l in range(1, L):
        parameters['W' + str(l)] = np.random.randn(layer_dims[l], layer_dims[l-1]) / np.sqrt(layer_dims[l-1]) #*0.01
        parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))
        
        assert(parameters['W' + str(l)].shape == (layer_dims[l], layer_dims[l-1]))
        assert(parameters['b' + str(l)].shape == (layer_dims[l], 1))

        
    return parameters

def linear_forward(A, W, b):
    """
    Implement the linear part of a layer's forward propagation.

    Arguments:
    A -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)

    Returns:
    Z -- the input of the activation function, also called pre-activation parameter 
    cache -- a python dictionary containing "A", "W" and "b" ; stored for computing the backward pass efficiently
    """
    
    Z = np.dot(W,A)+b
    
    assert(Z.shape == (W.shape[0], A.shape[1]))
    cache = (A, W, b)
    
    return Z, cache

def linear_activation_forward(A_prev, W, b, activation):
    """
    Implement the forward propagation for the LINEAR->ACTIVATION layer

    Arguments:
    A_prev -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"

    Returns:
    A -- the output of the activation function, also called the post-activation value 
    cache -- a python dictionary containing "linear_cache" and "activation_cache";
             stored for computing the backward pass efficiently
    """
    
    if activation == "sigmoid":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = sigmoid(Z)
    
    elif activation == "relu":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = relu(Z)
    
    assert (A.shape == (W.shape[0], A_prev.shape[1]))
    cache = (linear_cache, activation_cache)

    return A, cache

def L_model_forward(X, parameters):
    """
    Implement forward propagation for the [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID computation
    
    Arguments:
    X -- data, numpy array of shape (input size, number of examples)
    parameters -- output of initialize_parameters_deep()
    
    Returns:
    AL -- last post-activation value
    caches -- list of caches containing:
                every cache of linear_relu_forward() (there are L-1 of them, indexed from 0 to L-2)
                the cache of linear_sigmoid_forward() (there is one, indexed L-1)
    """

    caches = []
    A = X
    L = len(parameters) // 2                  # number of layers in the neural network
    
    # Implement [LINEAR -> RELU]*(L-1). Add "cache" to the "caches" list.
    for l in range(1, L):
        A_prev = A 
        A, cache = linear_activation_forward(A_prev, parameters["W"+str(l)], parameters["b"+str(l)], activation="relu")
        caches.append(cache)
    
    # Implement LINEAR -> SIGMOID. Add "cache" to the "caches" list.
    AL, cache = linear_activation_forward(A, parameters["W"+str(L)], parameters["b"+str(L)], activation="sigmoid")
    caches.append(cache)
    
    assert(AL.shape == (1,X.shape[1]))
            
    return AL, caches

def compute_cost(AL, Y, loss="crossentropy"):
    """
    Implement the cost function

    Arguments:
    AL -- probability vector corresponding to your label predictions, shape (1, number of examples)
    Y -- true "label" vector (for example: containing 0 if non-cat, 1 if cat), shape (1, number of examples)

    Returns:
    cost -- cross-entropy or mse cost
    """
    
    m = Y.shape[1]

    # Compute loss from aL and y.
    if loss == "crossentropy":
      cost = (1./m) * (-np.dot(Y,np.log(AL).T) - np.dot(1-Y, np.log(1-AL).T))
    
    elif loss == "mse":
      cost = (1./m) * (np.sum((AL-Y)**2,axis=1, keepdims=True))
    
    cost = np.squeeze(cost)      # To make sure the cost's shape is what we expect (e.g. this turns [[17]] into 17).
    assert(cost.shape == ())
    
    return cost

def linear_backward(dZ, cache):
    """
    Implement the linear portion of backward propagation for a single layer (layer l)

    Arguments:
    dZ -- Gradient of the cost with respect to the linear output (of current layer l)
    cache -- tuple of values (A_prev, W, b) coming from the forward propagation in the current layer

    Returns:
    dA_prev -- Gradient of the cost with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the cost with respect to W (current layer l), same shape as W
    db -- Gradient of the cost with respect to b (current layer l), same shape as b
    """
    A_prev, W, b = cache
    m = A_prev.shape[1]

    dW = 1./m * np.dot(dZ,A_prev.T)
    db = 1./m * np.sum(dZ, axis = 1, keepdims = True)
    dA_prev = np.dot(W.T,dZ)
    
    assert (dA_prev.shape == A_prev.shape)
    assert (dW.shape == W.shape)
    assert (db.shape == b.shape)
    
    return dA_prev, dW, db

def linear_activation_backward(dA, cache, activation):
    """
    Implement the backward propagation for the LINEAR->ACTIVATION layer.
    
    Arguments:
    dA -- post-activation gradient for current layer l 
    cache -- tuple of values (linear_cache, activation_cache) we store for computing backward propagation efficiently
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"
    
    Returns:
    dA_prev -- Gradient of the cost with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the cost with respect to W (current layer l), same shape as W
    db -- Gradient of the cost with respect to b (current layer l), same shape as b
    """
    linear_cache, activation_cache = cache
    
    if activation == "relu":
        dZ = relu_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
        
    elif activation == "sigmoid":
        dZ = sigmoid_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
    
    return dA_prev, dW, db

def L_model_backward(AL, Y, caches, loss="crossentropy"):
    """
    Implement the backward propagation for the [LINEAR->RELU] * (L-1) -> LINEAR -> SIGMOID group
    
    Arguments:
    AL -- probability vector, output of the forward propagation (L_model_forward())
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat)
    caches -- list of caches containing:
                every cache of linear_activation_forward() with "relu" (there are (L-1) or them, indexes from 0 to L-2)
                the cache of linear_activation_forward() with "sigmoid" (there is one, index L-1)
    
    Returns:
    grads -- A dictionary with the gradients
             grads["dA" + str(l)] = ... 
             grads["dW" + str(l)] = ...
             grads["db" + str(l)] = ... 
    """
    grads = {}
    L = len(caches) # the number of layers
    m = AL.shape[1]
    Y = Y.reshape(AL.shape) # after this line, Y is the same shape as AL
    
    # Initializing the backpropagation

    if loss == "crossentropy":
      dAL = - (np.divide(Y, AL) - np.divide(1 - Y, 1 - AL))
    
    elif loss == "mse":
      dAL = 2*(AL-Y)
    
    # Lth layer (SIGMOID -> LINEAR) gradients. Inputs: "AL, Y, caches". Outputs: "grads["dAL"], grads["dWL"], grads["dbL"]
    current_cache = caches[L-1]
    grads["dA" + str(L-1)], grads["dW" + str(L)], grads["db" + str(L)] = linear_activation_backward(dAL, current_cache, activation = "sigmoid")
    
    for l in reversed(range(L-1)):
        # lth layer: (RELU -> LINEAR) gradients.
        current_cache = caches[l]
        dA_prev_temp, dW_temp, db_temp = linear_activation_backward(grads["dA" + str(l + 1)], current_cache, activation = "relu")
        grads["dA" + str(l)] = dA_prev_temp
        grads["dW" + str(l + 1)] = dW_temp
        grads["db" + str(l + 1)] = db_temp

    return grads

def update_parameters(parameters, grads, learning_rate):
    """
    Update parameters using gradient descent
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    grads -- python dictionary containing your gradients, output of L_model_backward
    
    Returns:
    parameters -- python dictionary containing your updated parameters 
                  parameters["W" + str(l)] = ... 
                  parameters["b" + str(l)] = ...
    """
    
    L = len(parameters) // 2 # number of layers in the neural network

    # Update rule for each parameter. Use a for loop.
    for l in range(L):
        parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * grads["dW" + str(l+1)]
        parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * grads["db" + str(l+1)]
        
    return parameters

def predict(X, y, parameters, loss="crossentropy"):
    """
    This function is used to predict the results of a  L-layer neural network.
    
    Arguments:
    X -- data set of examples you would like to label
    parameters -- parameters of the trained model
    
    Returns:
    p -- predictions for the given dataset X
    """
    m = X.shape[1]
    n = len(parameters) // 2 # number of layers in the neural network

    if loss == "crossentropy":
     
      p = np.zeros((1,m))
        
      # Forward propagation
      probas, caches = L_model_forward(X, parameters)
        
      # convert probas to 0/1 predictions
      for i in range(0, probas.shape[1]):
          if probas[0,i] > 0.5:
            p[0,i] = 1
          else:
            p[0,i] = 0
      
      print("Accuracy: "  + str(np.sum((p == y)/m)))

    elif loss == "mse":

      p, caches = L_model_forward(X, parameters)

      print("Accuracy: "  + str((1/m)*np.sum(p-y)**2))
    
    #print results
    #print ("predictions: " + str(p))
    #print ("true labels: " + str(y))
    
    return p

def print_mislabeled_images(classes, X, y, p):
    """
    Plots images where predictions and truth were different.
    X -- dataset
    y -- true labels
    p -- predictions
    """
    a = p + y
    mislabeled_indices = np.asarray(np.where(a == 1))
    plt.rcParams['figure.figsize'] = (40.0, 40.0) # set default size of plots
    num_images = len(mislabeled_indices[0])
    for i in range(num_images):
        index = mislabeled_indices[1][i]
        
        plt.subplot(2, num_images, i + 1)
        plt.imshow(X[:,index].reshape(64,64,3), interpolation='nearest')
        plt.axis('off')
        plt.title("Prediction: " + classes[int(p[0,index])].decode("utf-8") + " \n Class: " + classes[y[0,index]].decode("utf-8"))

def train_model(X, Y, layers_dims, learning_rate = 0.0075, num_iterations = 3000, print_cost=False, loss="crossentropy"):
    """
    Implements a L-layer neural network: [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID.
    
    Arguments:
    X -- data, numpy array of shape (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if cat, 1 if non-cat), of shape (1, number of examples)
    layers_dims -- list containing the input size and each layer size, of length (number of layers + 1).
    learning_rate -- learning rate of the gradient descent update rule
    num_iterations -- number of iterations of the optimization loop
    print_cost -- if True, it prints the cost every 100 steps
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """

    np.random.seed(1)
    costs = []                         # keep track of cost
    
    parameters = initialize_parameters_deep(layers_dims)
    
    # Loop (gradient descent)
    for i in range(0, num_iterations):

        AL, caches = L_model_forward(X, parameters)
        
        # Compute cost.
        cost = compute_cost(AL, Y, loss=loss)
    
        # Backward propagation.
        grads = L_model_backward(AL, Y, caches, loss=loss)
 
        # Update parameters.
        parameters = update_parameters(parameters, grads, learning_rate)
                
        # Print the cost every 100 training example
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
        if print_cost and i % 100 == 0:
            costs.append(cost)
            
    # plot the cost
    plt.plot(np.squeeze(costs))
    plt.ylabel('cost')
    plt.xlabel('iterations (per hundreds)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    
    return parameters

# %% [markdown]
# # Now we train and test our NN on binary image classification using cat vs noncat

# %%
# !git clone https://github.com/simonme42/ANN_experiments.git
# Out:
# Cloning into 'ANN_experiments'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 66 (delta 30), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (66/66), done.

# %%
def load_data():
  train_dataset = h5py.File("ANN_experiments/datasets/train_catvnoncat.h5", "r")
  train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
  train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

  test_dataset = h5py.File("ANN_experiments/datasets/test_catvnoncat.h5", "r")
  test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
  test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

  classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
  train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
  test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
  return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1).T   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1).T

# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.
test_x = test_x_flatten/255.

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
# Out:
# train_x's shape: (12288, 209)
# test_x's shape: (12288, 50)

# %%
layers_dims = [train_x.shape[0], 20, 7, 5, 1]

parameters = train_model(train_x, train_y, layers_dims, num_iterations = 2000, print_cost = True, loss="crossentropy")
# Out:
# Cost after iteration 0: 0.771749
# Cost after iteration 100: 0.672053
# Cost after iteration 200: 0.648263
# Cost after iteration 300: 0.611507
# Cost after iteration 400: 0.567047
# Cost after iteration 500: 0.540138
# Cost after iteration 600: 0.527930
# Cost after iteration 700: 0.465477
# Cost after iteration 800: 0.369126
# Cost after iteration 900: 0.391747
# Cost after iteration 1000: 0.315187
# Cost after iteration 1100: 0.272700
# Cost after iteration 1200: 0.237419
# Cost after iteration 1300: 0.199601
# Cost after iteration 1400: 0.189263
# Cost after iteration 1500: 0.161189
# Cost after iteration 1600: 0.148214
# Cost after iteration 1700: 0.137775
# Cost after iteration 1800: 0.129740
# Cost after iteration 1900: 0.121225

# %%
pred_train = predict(train_x, train_y, parameters)
pred_test = predict(test_x, test_y, parameters)
# Out:
# Accuracy: 0.9808612440191385
# Accuracy: 0.8

# %%
print_mislabeled_images(classes, test_x, test_y, pred_test)

# %% [markdown]
# ## Now we use our NN implementation for a Regression task (adding 2 numbers)

# %%
def create_mse_data(low, high, m, train_test_split=0.2):

  mse_X = np.random.randint(low,high=high, size=(2,m))
  mse_X_scaled = mse_X/(high*2)

  mse_Y = (mse_X[0,:]+mse_X[1,:]).reshape(1,mse_X.shape[1])
  mse_Y_scaled = mse_Y/(high*2)

  mse_X_train = mse_X_scaled[:,0:int(m*train_test_split)]
  mse_X_test = mse_X_scaled[:,int(m*train_test_split):]
  mse_Y_train = mse_Y_scaled[:,0:int(m*train_test_split)]
  mse_Y_test = mse_Y_scaled[:,int(m*train_test_split):]

  return (mse_X_train,mse_X_test,mse_Y_train,mse_Y_test)


(mse_X_train,mse_X_test,mse_Y_train,mse_Y_test) = create_mse_data(0,50,1000)

layers_dims_mse = [mse_X_train.shape[0],5,4,1]

# %%
parameters = train_model(mse_X_train, mse_Y_train, layers_dims_mse, num_iterations = 50000, print_cost = True, loss="mse", learning_rate = 0.01)
# Out:
# Cost after iteration 0: 0.043270
# Cost after iteration 100: 0.043140
# Cost after iteration 200: 0.042965
# Cost after iteration 300: 0.042729
# Cost after iteration 400: 0.042441
# Cost after iteration 500: 0.042192
# Cost after iteration 600: 0.042034
# Cost after iteration 700: 0.041926
# Cost after iteration 800: 0.041836
# Cost after iteration 900: 0.041745
# Cost after iteration 1000: 0.041645
# Cost after iteration 1100: 0.041541
# Cost after iteration 1200: 0.041432
# Cost after iteration 1300: 0.041318
# Cost after iteration 1400: 0.041202
# Cost after iteration 1500: 0.041092
# Cost after iteration 1600: 0.040982
# Cost after iteration 1700: 0.040877
# Cost after iteration 1800: 0.040780
# Cost after iteration 1900: 0.040703
# Cost after iteration 2000: 0.040633
# Cost after iteration 2100: 0.040567
# Cost after iteration 2200: 0.040507
# Cost after iteration 2300: 0.040451
# Cost after iteration 2400: 0.040397
# Cost after iteration 2500: 0.040346
# Cost after iteration 2600: 0.040295
# Cost after iteration 2700: 0.040245
# Cost after iteration 2800: 0.040195
# Cost after iteration 2900: 0.040144
# Cost after iteration 3000: 0.040092
# Cost after iteration 3100: 0.040039
# Cost after iteration 3200: 0.039985
# Cost after iteration 3300: 0.039929
# Cost after iteration 3400: 0.039875
# Cost after iteration 3500: 0.039820
# Cost after iteration 3600: 0.039764
# Cost after iteration 3700: 0.039707
# Cost after iteration 3800: 0.039650
# Cost after iteration 3900: 0.039592
# Cost after iteration 4000: 0.039533
# Cost after iteration 4100: 0.039472
# Cost after iteration 4200: 0.039409
# Cost after iteration 4300: 0.039345
# Cost after iteration 4400: 0.039278
# Cost after iteration 4500: 0.039210
# Cost after iteration 4600: 0.039140
# Cost after iteration 4700: 0.039071
# Cost after iteration 4800: 0.038999
# Cost after iteration 4900: 0.038926
# Cost after iteration 5000: 0.038846
# Cost after iteration 5100: 0.038757
# Cost after iteration 5200: 0.038656
# Cost after iteration 5300: 0.038549
# Cost after iteration 5400: 0.038438
# Cost after iteration 5500: 0.038325
# Cost after iteration 5600: 0.038213
# Cost after iteration 5700: 0.038100
# Cost after iteration 5800: 0.037983
# Cost after iteration 5900: 0.037860
# Cost after iteration 6000: 0.037736
# Cost after iteration 6100: 0.037608
# Cost after iteration 6200: 0.037474
# Cost after iteration 6300: 0.037329
# Cost after iteration 6400: 0.037179
# Cost after iteration 6500: 0.037024
# Cost after iteration 6600: 0.036866
# Cost after iteration 6700: 0.036706
# Cost after iteration 6800: 0.036541
# Cost after iteration 6900: 0.036378
# Cost after iteration 7000: 0.036212
# Cost after iteration 7100: 0.036041
# Cost after iteration 7200: 0.035879
# Cost after iteration 7300: 0.035715
# Cost after iteration 7400: 0.035544
# Cost after iteration 7500: 0.035366
# Cost after iteration 7600: 0.035187
# Cost after iteration 7700: 0.035010
# Cost after iteration 7800: 0.034831
# Cost after iteration 7900: 0.034652
# Cost after iteration 8000: 0.034470
# Cost after iteration 8100: 0.034285
# Cost after iteration 8200: 0.034095
# Cost after iteration 8300: 0.033903
# Cost after iteration 8400: 0.033708
# Cost after iteration 8500: 0.033511
# Cost after iteration 8600: 0.033308
# Cost after iteration 8700: 0.033100
# Cost after iteration 8800: 0.032890
# Cost after iteration 8900: 0.032675
# Cost after iteration 9000: 0.032457
# Cost after iteration 9100: 0.032233
# Cost after iteration 9200: 0.032006
# Cost after iteration 9300: 0.031774
# Cost after iteration 9400: 0.031538
# Cost after iteration 9500: 0.031298
# Cost after iteration 9600: 0.031055
# Cost after iteration 9700: 0.030808
# Cost after iteration 9800: 0.030556
# Cost after iteration 9900: 0.030301
# Cost after iteration 10000: 0.030041
# Cost after iteration 10100: 0.029775
# Cost after iteration 10200: 0.029505
# Cost after iteration 10300: 0.029230
# Cost after iteration 10400: 0.028951
# Cost after iteration 10500: 0.028667
# Cost after iteration 10600: 0.028379
# Cost after iteration 10700: 0.028085
# Cost after iteration 10800: 0.027787
# Cost after iteration 10900: 0.027485
# Cost after iteration 11000: 0.027177
# Cost after iteration 11100: 0.026865
# Cost after iteration 11200: 0.026548
# Cost after iteration 11300: 0.026225
# Cost after iteration 11400: 0.025899
# Cost after iteration 11500: 0.025568
# Cost after iteration 11600: 0.025235
# Cost after iteration 11700: 0.024898
# Cost after iteration 11800: 0.024558
# Cost after iteration 11900: 0.024213
# Cost after iteration 12000: 0.023866
# Cost after iteration 12100: 0.023514
# Cost after iteration 12200: 0.023159
# Cost after iteration 12300: 0.022800
# Cost after iteration 12400: 0.022436
# Cost after iteration 12500: 0.022069
# Cost after iteration 12600: 0.021698
# Cost after iteration 12700: 0.021326
# Cost after iteration 12800: 0.020952
# Cost after iteration 12900: 0.020576
# Cost after iteration 13000: 0.020198
# Cost after iteration 13100: 0.019816
# Cost after iteration 13200: 0.019434
# Cost after iteration 13300: 0.019050
# Cost after iteration 13400: 0.018667
# Cost after iteration 13500: 0.018283
# Cost after iteration 13600: 0.017900
# Cost after iteration 13700: 0.017516
# Cost after iteration 13800: 0.017134
# Cost after iteration 13900: 0.016752
# Cost after iteration 14000: 0.016371
# Cost after iteration 14100: 0.015996
# Cost after iteration 14200: 0.015624
# Cost after iteration 14300: 0.015254
# Cost after iteration 14400: 0.014888
# Cost after iteration 14500: 0.014528
# Cost after iteration 14600: 0.014169
# Cost after iteration 14700: 0.013816
# Cost after iteration 14800: 0.013469
# Cost after iteration 14900: 0.013126
# Cost after iteration 15000: 0.012787
# Cost after iteration 15100: 0.012452
# Cost after iteration 15200: 0.012122
# Cost after iteration 15300: 0.011796
# Cost after iteration 15400: 0.011476
# Cost after iteration 15500: 0.011160
# Cost after iteration 15600: 0.010850
# Cost after iteration 15700: 0.010544
# Cost after iteration 15800: 0.010245
# Cost after iteration 15900: 0.009952
# Cost after iteration 16000: 0.009664
# Cost after iteration 16100: 0.009383
# Cost after iteration 16200: 0.009107
# Cost after iteration 16300: 0.008838
# Cost after iteration 16400: 0.008575
# Cost after iteration 16500: 0.008320
# Cost after iteration 16600: 0.008072
# Cost after iteration 16700: 0.007832
# Cost after iteration 16800: 0.007600
# Cost after iteration 16900: 0.007374
# Cost after iteration 17000: 0.007155
# Cost after iteration 17100: 0.006943
# Cost after iteration 17200: 0.006737
# Cost after iteration 17300: 0.006539
# Cost after iteration 17400: 0.006347
# Cost after iteration 17500: 0.006162
# Cost after iteration 17600: 0.005983
# Cost after iteration 17700: 0.005810
# Cost after iteration 17800: 0.005643
# Cost after iteration 17900: 0.005482
# Cost after iteration 18000: 0.005326
# Cost after iteration 18100: 0.005177
# Cost after iteration 18200: 0.005032
# Cost after iteration 18300: 0.004893
# Cost after iteration 18400: 0.004760
# Cost after iteration 18500: 0.004630
# Cost after iteration 18600: 0.004506
# Cost after iteration 18700: 0.004386
# Cost after iteration 18800: 0.004271
# Cost after iteration 18900: 0.004160
# Cost after iteration 19000: 0.004053
# Cost after iteration 19100: 0.003950
# Cost after iteration 19200: 0.003852
# Cost after iteration 19300: 0.003757
# Cost after iteration 19400: 0.003665
# Cost after iteration 19500: 0.003576
# Cost after iteration 19600: 0.003491
# Cost after iteration 19700: 0.003409
# Cost after iteration 19800: 0.003331
# Cost after iteration 19900: 0.003255
# Cost after iteration 20000: 0.003183
# Cost after iteration 20100: 0.003113
# Cost after iteration 20200: 0.003045
# Cost after iteration 20300: 0.002981
# Cost after iteration 20400: 0.002919
# Cost after iteration 20500: 0.002859
# Cost after iteration 20600: 0.002802
# Cost after iteration 20700: 0.002746
# Cost after iteration 20800: 0.002693
# Cost after iteration 20900: 0.002642
# Cost after iteration 21000: 0.002593
# Cost after iteration 21100: 0.002545
# Cost after iteration 21200: 0.002500
# Cost after iteration 21300: 0.002456
# Cost after iteration 21400: 0.002413
# Cost after iteration 21500: 0.002372
# Cost after iteration 21600: 0.002333
# Cost after iteration 21700: 0.002295
# Cost after iteration 21800: 0.002258
# Cost after iteration 21900: 0.002222
# Cost after iteration 22000: 0.002188
# Cost after iteration 22100: 0.002154
# Cost after iteration 22200: 0.002122
# Cost after iteration 22300: 0.002091
# Cost after iteration 22400: 0.002061
# Cost after iteration 22500: 0.002032
# Cost after iteration 22600: 0.002004
# Cost after iteration 22700: 0.001977
# Cost after iteration 22800: 0.001950
# Cost after iteration 22900: 0.001925
# Cost after iteration 23000: 0.001900
# Cost after iteration 23100: 0.001877
# Cost after iteration 23200: 0.001854
# Cost after iteration 23300: 0.001831
# Cost after iteration 23400: 0.001810
# Cost after iteration 23500: 0.001789
# Cost after iteration 23600: 0.001768
# Cost after iteration 23700: 0.001749
# Cost after iteration 23800: 0.001729
# Cost after iteration 23900: 0.001711
# Cost after iteration 24000: 0.001693
# Cost after iteration 24100: 0.001675
# Cost after iteration 24200: 0.001658
# Cost after iteration 24300: 0.001641
# Cost after iteration 24400: 0.001625
# Cost after iteration 24500: 0.001609
# Cost after iteration 24600: 0.001594
# Cost after iteration 24700: 0.001579
# Cost after iteration 24800: 0.001564
# Cost after iteration 24900: 0.001550
# Cost after iteration 25000: 0.001536
# Cost after iteration 25100: 0.001523
# Cost after iteration 25200: 0.001510
# Cost after iteration 25300: 0.001497
# Cost after iteration 25400: 0.001484
# Cost after iteration 25500: 0.001472
# Cost after iteration 25600: 0.001460
# Cost after iteration 25700: 0.001448
# Cost after iteration 25800: 0.001437
# Cost after iteration 25900: 0.001425
# Cost after iteration 26000: 0.001414
# Cost after iteration 26100: 0.001404
# Cost after iteration 26200: 0.001393
# Cost after iteration 26300: 0.001383
# Cost after iteration 26400: 0.001372
# Cost after iteration 26500: 0.001362
# Cost after iteration 26600: 0.001353
# Cost after iteration 26700: 0.001343
# Cost after iteration 26800: 0.001334
# Cost after iteration 26900: 0.001324
# Cost after iteration 27000: 0.001315
# Cost after iteration 27100: 0.001306
# Cost after iteration 27200: 0.001297
# Cost after iteration 27300: 0.001289
# Cost after iteration 27400: 0.001280
# Cost after iteration 27500: 0.001272
# Cost after iteration 27600: 0.001264
# Cost after iteration 27700: 0.001255
# Cost after iteration 27800: 0.001247
# Cost after iteration 27900: 0.001240
# Cost after iteration 28000: 0.001232
# Cost after iteration 28100: 0.001224
# Cost after iteration 28200: 0.001217
# Cost after iteration 28300: 0.001209
# Cost after iteration 28400: 0.001202
# Cost after iteration 28500: 0.001195
# Cost after iteration 28600: 0.001188
# Cost after iteration 28700: 0.001181
# Cost after iteration 28800: 0.001174
# Cost after iteration 28900: 0.001167
# Cost after iteration 29000: 0.001160
# Cost after iteration 29100: 0.001154
# Cost after iteration 29200: 0.001147
# Cost after iteration 29300: 0.001141
# Cost after iteration 29400: 0.001134
# Cost after iteration 29500: 0.001128
# Cost after iteration 29600: 0.001122
# Cost after iteration 29700: 0.001116
# Cost after iteration 29800: 0.001110
# Cost after iteration 29900: 0.001104
# Cost after iteration 30000: 0.001098
# Cost after iteration 30100: 0.001092
# Cost after iteration 30200: 0.001086
# Cost after iteration 30300: 0.001081
# Cost after iteration 30400: 0.001075
# Cost after iteration 30500: 0.001069
# Cost after iteration 30600: 0.001064
# Cost after iteration 30700: 0.001058
# Cost after iteration 30800: 0.001053
# Cost after iteration 30900: 0.001047
# Cost after iteration 31000: 0.001042
# Cost after iteration 31100: 0.001037
# Cost after iteration 31200: 0.001032
# Cost after iteration 31300: 0.001027
# Cost after iteration 31400: 0.001021
# Cost after iteration 31500: 0.001016
# Cost after iteration 31600: 0.001011
# Cost after iteration 31700: 0.001007
# Cost after iteration 31800: 0.001002
# Cost after iteration 31900: 0.000997
# Cost after iteration 32000: 0.000992
# Cost after iteration 32100: 0.000987
# Cost after iteration 32200: 0.000983
# Cost after iteration 32300: 0.000978
# Cost after iteration 32400: 0.000974
# Cost after iteration 32500: 0.000969
# Cost after iteration 32600: 0.000965
# Cost after iteration 32700: 0.000960
# Cost after iteration 32800: 0.000956
# Cost after iteration 32900: 0.000952
# Cost after iteration 33000: 0.000947
# Cost after iteration 33100: 0.000943
# Cost after iteration 33200: 0.000939
# Cost after iteration 33300: 0.000935
# Cost after iteration 33400: 0.000931
# Cost after iteration 33500: 0.000927
# Cost after iteration 33600: 0.000923
# Cost after iteration 33700: 0.000919
# Cost after iteration 33800: 0.000915
# Cost after iteration 33900: 0.000911
# Cost after iteration 34000: 0.000907
# Cost after iteration 34100: 0.000903
# Cost after iteration 34200: 0.000899
# Cost after iteration 34300: 0.000895
# Cost after iteration 34400: 0.000892
# Cost after iteration 34500: 0.000888
# Cost after iteration 34600: 0.000884
# Cost after iteration 34700: 0.000881
# Cost after iteration 34800: 0.000877
# Cost after iteration 34900: 0.000874
# Cost after iteration 35000: 0.000870
# Cost after iteration 35100: 0.000867
# Cost after iteration 35200: 0.000863
# Cost after iteration 35300: 0.000860
# Cost after iteration 35400: 0.000856
# Cost after iteration 35500: 0.000853
# Cost after iteration 35600: 0.000850
# Cost after iteration 35700: 0.000846
# Cost after iteration 35800: 0.000843
# Cost after iteration 35900: 0.000840
# Cost after iteration 36000: 0.000837
# Cost after iteration 36100: 0.000833
# Cost after iteration 36200: 0.000830
# Cost after iteration 36300: 0.000827
# Cost after iteration 36400: 0.000824
# Cost after iteration 36500: 0.000821
# Cost after iteration 36600: 0.000818
# Cost after iteration 36700: 0.000815
# Cost after iteration 36800: 0.000812
# Cost after iteration 36900: 0.000809
# Cost after iteration 37000: 0.000806
# Cost after iteration 37100: 0.000803
# Cost after iteration 37200: 0.000800
# Cost after iteration 37300: 0.000797
# Cost after iteration 37400: 0.000794
# Cost after iteration 37500: 0.000791
# Cost after iteration 37600: 0.000788
# Cost after iteration 37700: 0.000785
# Cost after iteration 37800: 0.000783
# Cost after iteration 37900: 0.000780
# Cost after iteration 38000: 0.000777
# Cost after iteration 38100: 0.000774
# Cost after iteration 38200: 0.000772
# Cost after iteration 38300: 0.000769
# Cost after iteration 38400: 0.000766
# Cost after iteration 38500: 0.000764
# Cost after iteration 38600: 0.000761
# Cost after iteration 38700: 0.000758
# Cost after iteration 38800: 0.000756
# Cost after iteration 38900: 0.000753
# Cost after iteration 39000: 0.000751
# Cost after iteration 39100: 0.000748
# Cost after iteration 39200: 0.000746
# Cost after iteration 39300: 0.000743
# Cost after iteration 39400: 0.000741
# Cost after iteration 39500: 0.000738
# Cost after iteration 39600: 0.000736
# Cost after iteration 39700: 0.000733
# Cost after iteration 39800: 0.000731
# Cost after iteration 39900: 0.000728
# Cost after iteration 40000: 0.000726
# Cost after iteration 40100: 0.000724
# Cost after iteration 40200: 0.000721
# Cost after iteration 40300: 0.000719
# Cost after iteration 40400: 0.000717
# Cost after iteration 40500: 0.000714
# Cost after iteration 40600: 0.000712
# Cost after iteration 40700: 0.000710
# Cost after iteration 40800: 0.000708
# Cost after iteration 40900: 0.000706
# Cost after iteration 41000: 0.000704
# Cost after iteration 41100: 0.000702
# Cost after iteration 41200: 0.000699
# Cost after iteration 41300: 0.000697
# Cost after iteration 41400: 0.000695
# Cost after iteration 41500: 0.000693
# Cost after iteration 41600: 0.000691
# Cost after iteration 41700: 0.000689
# Cost after iteration 41800: 0.000687
# Cost after iteration 41900: 0.000685
# Cost after iteration 42000: 0.000683
# Cost after iteration 42100: 0.000681
# Cost after iteration 42200: 0.000679
# Cost after iteration 42300: 0.000677
# Cost after iteration 42400: 0.000675
# Cost after iteration 42500: 0.000673
# Cost after iteration 42600: 0.000671
# Cost after iteration 42700: 0.000669
# Cost after iteration 42800: 0.000667
# Cost after iteration 42900: 0.000665
# Cost after iteration 43000: 0.000663
# Cost after iteration 43100: 0.000661
# Cost after iteration 43200: 0.000660
# Cost after iteration 43300: 0.000658
# Cost after iteration 43400: 0.000656
# Cost after iteration 43500: 0.000654
# Cost after iteration 43600: 0.000652
# Cost after iteration 43700: 0.000650
# Cost after iteration 43800: 0.000649
# Cost after iteration 43900: 0.000647
# Cost after iteration 44000: 0.000645
# Cost after iteration 44100: 0.000643
# Cost after iteration 44200: 0.000641
# Cost after iteration 44300: 0.000640
# Cost after iteration 44400: 0.000638
# Cost after iteration 44500: 0.000636
# Cost after iteration 44600: 0.000635
# Cost after iteration 44700: 0.000633
# Cost after iteration 44800: 0.000631
# Cost after iteration 44900: 0.000630
# Cost after iteration 45000: 0.000628
# Cost after iteration 45100: 0.000626
# Cost after iteration 45200: 0.000625
# Cost after iteration 45300: 0.000623
# Cost after iteration 45400: 0.000622
# Cost after iteration 45500: 0.000620
# Cost after iteration 45600: 0.000619
# Cost after iteration 45700: 0.000617
# Cost after iteration 45800: 0.000615
# Cost after iteration 45900: 0.000614
# Cost after iteration 46000: 0.000612
# Cost after iteration 46100: 0.000611
# Cost after iteration 46200: 0.000609
# Cost after iteration 46300: 0.000608
# Cost after iteration 46400: 0.000606
# Cost after iteration 46500: 0.000605
# Cost after iteration 46600: 0.000603
# Cost after iteration 46700: 0.000602
# Cost after iteration 46800: 0.000600
# Cost after iteration 46900: 0.000599
# Cost after iteration 47000: 0.000597
# Cost after iteration 47100: 0.000596
# Cost after iteration 47200: 0.000595
# Cost after iteration 47300: 0.000593
# Cost after iteration 47400: 0.000592
# Cost after iteration 47500: 0.000591
# Cost after iteration 47600: 0.000589
# Cost after iteration 47700: 0.000588
# Cost after iteration 47800: 0.000586
# Cost after iteration 47900: 0.000585
# Cost after iteration 48000: 0.000584
# Cost after iteration 48100: 0.000582
# Cost after iteration 48200: 0.000581
# Cost after iteration 48300: 0.000580
# Cost after iteration 48400: 0.000578
# Cost after iteration 48500: 0.000577
# Cost after iteration 48600: 0.000576
# Cost after iteration 48700: 0.000574
# Cost after iteration 48800: 0.000573
# Cost after iteration 48900: 0.000572
# Cost after iteration 49000: 0.000571
# Cost after iteration 49100: 0.000569
# Cost after iteration 49200: 0.000568
# Cost after iteration 49300: 0.000567
# Cost after iteration 49400: 0.000566
# Cost after iteration 49500: 0.000564
# Cost after iteration 49600: 0.000563
# Cost after iteration 49700: 0.000562
# Cost after iteration 49800: 0.000561
# Cost after iteration 49900: 0.000559

# %%
pred_train = predict(mse_X_train, mse_Y_train, parameters, loss="mse")

p, caches = L_model_forward(mse_X_train, parameters)
print((p*100-mse_Y_train*100)[:,0:50])
# Out:
# Accuracy: 0.0009190238216227141
# [[-0.54081973 -1.055276   -8.81147818  1.25808221 -0.18555631 -1.03112768
#    0.65210088  4.13872     1.02687026  0.6053064  -0.55262917 -1.35160845
#   -1.70568731 -1.89656725  0.05231446 -0.40780545  6.91498991 -0.76240832
#    4.62103055 -1.1921707   1.1520427   3.74444842  0.06050308  0.43108827
#   -0.01311604 -1.19988279 -0.09164843  0.80897546  1.44728706 -0.27369664
#   -1.2465528  -0.13927086 -0.84373356 -0.37399937 -0.12026224  0.90465414
#    4.15607589  0.75409738 -0.27645131 -9.81147818 -1.15856523 -1.16907721
#    0.74084548  3.27260312 -0.87857424  1.15388046 -0.1101924  -1.32686049
#    0.5200139   1.20336568]]

# %%
pred_test = predict(mse_X_test, mse_Y_test, parameters, loss="mse")

p, caches = L_model_forward(mse_X_test, parameters)

print((mse_Y_test*100)[:,0:10])
print((p*100)[:,0:10])
print((p*100-mse_Y_test*100)[:,0:50])
# Out:
# Accuracy: 0.0019427354156169412
# [[11.  6. 35. 17. 65. 44. 58. 56. 25. 59.]]
# [[14.73247741 12.91498991 33.73214915 18.3828818  66.13687254 43.08735882
#   58.9850581  56.65210088 24.39302923 59.83425437]]
# [[  3.73247741   6.91498991  -1.26785085   1.3828818    1.13687254
#    -0.91264118   0.9850581    0.65210088  -0.60697077   0.83425437
#    -6.81147818  -0.72754173   0.53709166   2.50620762   1.26820388
#     0.93396104  -5.81147818  -2.70923532  -0.15117529  -1.20572183
#    -0.49443332   1.22405666  -0.18576893   0.6443137   -0.46484052
#    -1.03346009  -1.37056947 -12.81147818  -1.22913716  -1.90076362
#    -0.77242248   2.45375917  -1.12320907   1.06215928  -0.23064583
#     0.08689328  -0.07844007  -4.81147818   0.4544658   -0.09164843
#    -1.26785085  -0.76240832   0.13654523  -0.901797    -0.21930203
#     0.73396263  -0.2959224    0.8467069   -1.83949598   0.84570109]]

# %%
p*100
