# %% [markdown]
# <a href="https://colab.research.google.com/github/simonme42/ANN_experiments/blob/master/ANN_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ANN from scratch
#
# *   In this notebook, we implement an artificial neural network from scratch.
# *   All we need are a few standard python libraries
# *   At the end we´ll test our ANN implementation on image classification tasks

# %%
import numpy as np
import scipy
import h5py
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def sigmoid(Z):
    """
    Implements the sigmoid activation in numpy
    
    Arguments:
    Z -- numpy array of any shape
    
    Returns:
    A -- output of sigmoid(z), same shape as Z
    cache -- returns Z as well, useful during backpropagation
    """
    
    A = 1/(1+np.exp(-Z))
    cache = Z
    
    return A, cache

def relu(Z):
    """
    Implement the RELU function.

    Arguments:
    Z -- Output of the linear layer, of any shape

    Returns:
    A -- Post-activation parameter, of the same shape as Z
    cache -- a python dictionary containing "A" ; stored for computing the backward pass efficiently
    """
    
    A = np.maximum(0,Z)
    
    assert(A.shape == Z.shape)
    
    cache = Z 
    return A, cache


def relu_backward(dA, cache):
    """
    Implement the backward propagation for a single RELU unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the cost with respect to Z
    """
    
    Z = cache
    dZ = np.array(dA, copy=True) # just converting dz to a correct object.
    
    # When z <= 0, you should set dz to 0 as well. 
    dZ[Z <= 0] = 0
    
    assert (dZ.shape == Z.shape)
    
    return dZ

def sigmoid_backward(dA, cache):
    """
    Implement the backward propagation for a single SIGMOID unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the cost with respect to Z
    """
    
    Z = cache
    
    s = 1/(1+np.exp(-Z))
    dZ = dA * s * (1-s)
    
    assert (dZ.shape == Z.shape)
    
    return dZ



def initialize_parameters_deep(layer_dims):
    """
    Arguments:
    layer_dims -- python array (list) containing the dimensions of each layer in our network
    
    Returns:
    parameters -- python dictionary containing your parameters "W1", "b1", ..., "WL", "bL":
                    Wl -- weight matrix of shape (layer_dims[l], layer_dims[l-1])
                    bl -- bias vector of shape (layer_dims[l], 1)
    """
    
    #np.random.seed(1)
    parameters = {}
    L = len(layer_dims)            # number of layers in the network

    for l in range(1, L):
        parameters['W' + str(l)] = np.random.randn(layer_dims[l], layer_dims[l-1]) / np.sqrt(layer_dims[l-1]) #*0.01
        parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))
        
        assert(parameters['W' + str(l)].shape == (layer_dims[l], layer_dims[l-1]))
        assert(parameters['b' + str(l)].shape == (layer_dims[l], 1))

        
    return parameters

def linear_forward(A, W, b):
    """
    Implement the linear part of a layer's forward propagation.

    Arguments:
    A -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)

    Returns:
    Z -- the input of the activation function, also called pre-activation parameter 
    cache -- a python dictionary containing "A", "W" and "b" ; stored for computing the backward pass efficiently
    """
    
    Z = np.dot(W,A)+b
    
    assert(Z.shape == (W.shape[0], A.shape[1]))
    cache = (A, W, b)
    
    return Z, cache

def linear_activation_forward(A_prev, W, b, activation):
    """
    Implement the forward propagation for the LINEAR->ACTIVATION layer

    Arguments:
    A_prev -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"

    Returns:
    A -- the output of the activation function, also called the post-activation value 
    cache -- a python dictionary containing "linear_cache" and "activation_cache";
             stored for computing the backward pass efficiently
    """
    
    if activation == "sigmoid":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = sigmoid(Z)
    
    elif activation == "relu":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = relu(Z)
    
    assert (A.shape == (W.shape[0], A_prev.shape[1]))
    cache = (linear_cache, activation_cache)

    return A, cache

def L_model_forward(X, parameters):
    """
    Implement forward propagation for the [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID computation
    
    Arguments:
    X -- data, numpy array of shape (input size, number of examples)
    parameters -- output of initialize_parameters_deep()
    
    Returns:
    AL -- last post-activation value
    caches -- list of caches containing:
                every cache of linear_relu_forward() (there are L-1 of them, indexed from 0 to L-2)
                the cache of linear_sigmoid_forward() (there is one, indexed L-1)
    """

    caches = []
    A = X
    L = len(parameters) // 2                  # number of layers in the neural network
    
    # Implement [LINEAR -> RELU]*(L-1). Add "cache" to the "caches" list.
    for l in range(1, L):
        A_prev = A 
        A, cache = linear_activation_forward(A_prev, parameters["W"+str(l)], parameters["b"+str(l)], activation="relu")
        caches.append(cache)
    
    # Implement LINEAR -> SIGMOID. Add "cache" to the "caches" list.
    AL, cache = linear_activation_forward(A, parameters["W"+str(L)], parameters["b"+str(L)], activation="sigmoid")
    caches.append(cache)
    
    assert(AL.shape == (1,X.shape[1]))
            
    return AL, caches

def compute_cost(AL, Y, loss="crossentropy"):
    """
    Implement the cost function

    Arguments:
    AL -- probability vector corresponding to your label predictions, shape (1, number of examples)
    Y -- true "label" vector (for example: containing 0 if non-cat, 1 if cat), shape (1, number of examples)

    Returns:
    cost -- cross-entropy or mse cost
    """
    
    m = Y.shape[1]

    # Compute loss from aL and y.
    if loss == "crossentropy":
      cost = (1./m) * (-np.dot(Y,np.log(AL).T) - np.dot(1-Y, np.log(1-AL).T))
    
    elif loss == "mse":
      cost = (1./m) * (np.sum((AL-Y)**2,axis=1, keepdims=True))
    
    cost = np.squeeze(cost)      # To make sure the cost's shape is what we expect (e.g. this turns [[17]] into 17).
    assert(cost.shape == ())
    
    return cost

def linear_backward(dZ, cache):
    """
    Implement the linear portion of backward propagation for a single layer (layer l)

    Arguments:
    dZ -- Gradient of the cost with respect to the linear output (of current layer l)
    cache -- tuple of values (A_prev, W, b) coming from the forward propagation in the current layer

    Returns:
    dA_prev -- Gradient of the cost with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the cost with respect to W (current layer l), same shape as W
    db -- Gradient of the cost with respect to b (current layer l), same shape as b
    """
    A_prev, W, b = cache
    m = A_prev.shape[1]

    dW = 1./m * np.dot(dZ,A_prev.T)
    db = 1./m * np.sum(dZ, axis = 1, keepdims = True)
    dA_prev = np.dot(W.T,dZ)
    
    assert (dA_prev.shape == A_prev.shape)
    assert (dW.shape == W.shape)
    assert (db.shape == b.shape)
    
    return dA_prev, dW, db

def linear_activation_backward(dA, cache, activation):
    """
    Implement the backward propagation for the LINEAR->ACTIVATION layer.
    
    Arguments:
    dA -- post-activation gradient for current layer l 
    cache -- tuple of values (linear_cache, activation_cache) we store for computing backward propagation efficiently
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"
    
    Returns:
    dA_prev -- Gradient of the cost with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the cost with respect to W (current layer l), same shape as W
    db -- Gradient of the cost with respect to b (current layer l), same shape as b
    """
    linear_cache, activation_cache = cache
    
    if activation == "relu":
        dZ = relu_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
        
    elif activation == "sigmoid":
        dZ = sigmoid_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
    
    return dA_prev, dW, db

def L_model_backward(AL, Y, caches, loss="crossentropy"):
    """
    Implement the backward propagation for the [LINEAR->RELU] * (L-1) -> LINEAR -> SIGMOID group
    
    Arguments:
    AL -- probability vector, output of the forward propagation (L_model_forward())
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat)
    caches -- list of caches containing:
                every cache of linear_activation_forward() with "relu" (there are (L-1) or them, indexes from 0 to L-2)
                the cache of linear_activation_forward() with "sigmoid" (there is one, index L-1)
    
    Returns:
    grads -- A dictionary with the gradients
             grads["dA" + str(l)] = ... 
             grads["dW" + str(l)] = ...
             grads["db" + str(l)] = ... 
    """
    grads = {}
    L = len(caches) # the number of layers
    m = AL.shape[1]
    Y = Y.reshape(AL.shape) # after this line, Y is the same shape as AL
    
    # Initializing the backpropagation

    if loss == "crossentropy":
      dAL = - (np.divide(Y, AL) - np.divide(1 - Y, 1 - AL))
    
    elif loss == "mse":
      dAL = 2*(AL-Y)
    
    # Lth layer (SIGMOID -> LINEAR) gradients. Inputs: "AL, Y, caches". Outputs: "grads["dAL"], grads["dWL"], grads["dbL"]
    current_cache = caches[L-1]
    grads["dA" + str(L-1)], grads["dW" + str(L)], grads["db" + str(L)] = linear_activation_backward(dAL, current_cache, activation = "sigmoid")
    
    for l in reversed(range(L-1)):
        # lth layer: (RELU -> LINEAR) gradients.
        current_cache = caches[l]
        dA_prev_temp, dW_temp, db_temp = linear_activation_backward(grads["dA" + str(l + 1)], current_cache, activation = "relu")
        grads["dA" + str(l)] = dA_prev_temp
        grads["dW" + str(l + 1)] = dW_temp
        grads["db" + str(l + 1)] = db_temp

    return grads

def update_parameters(parameters, grads, learning_rate):
    """
    Update parameters using gradient descent
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    grads -- python dictionary containing your gradients, output of L_model_backward
    
    Returns:
    parameters -- python dictionary containing your updated parameters 
                  parameters["W" + str(l)] = ... 
                  parameters["b" + str(l)] = ...
    """
    
    L = len(parameters) // 2 # number of layers in the neural network

    # Update rule for each parameter. Use a for loop.
    for l in range(L):
        parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * grads["dW" + str(l+1)]
        parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * grads["db" + str(l+1)]
        
    return parameters

def predict(X, y, parameters, loss="crossentropy"):
    """
    This function is used to predict the results of a  L-layer neural network.
    
    Arguments:
    X -- data set of examples you would like to label
    parameters -- parameters of the trained model
    
    Returns:
    p -- predictions for the given dataset X
    """
    
    m = X.shape[1]
    n = len(parameters) // 2 # number of layers in the neural network
    p = np.zeros((1,m))
    
    # Forward propagation
    probas, caches = L_model_forward(X, parameters)

    
    # convert probas to 0/1 predictions
    for i in range(0, probas.shape[1]):
        if probas[0,i] > 0.5:
            p[0,i] = 1
        else:
            p[0,i] = 0
    
    #print results
    #print ("predictions: " + str(p))
    #print ("true labels: " + str(y))
    print("Accuracy: "  + str(np.sum((p == y)/m)))
        
    return p

def print_mislabeled_images(classes, X, y, p):
    """
    Plots images where predictions and truth were different.
    X -- dataset
    y -- true labels
    p -- predictions
    """
    a = p + y
    mislabeled_indices = np.asarray(np.where(a == 1))
    plt.rcParams['figure.figsize'] = (40.0, 40.0) # set default size of plots
    num_images = len(mislabeled_indices[0])
    for i in range(num_images):
        index = mislabeled_indices[1][i]
        
        plt.subplot(2, num_images, i + 1)
        plt.imshow(X[:,index].reshape(64,64,3), interpolation='nearest')
        plt.axis('off')
        plt.title("Prediction: " + classes[int(p[0,index])].decode("utf-8") + " \n Class: " + classes[y[0,index]].decode("utf-8"))

# %%
def train_model(X, Y, layers_dims, learning_rate = 0.0075, num_iterations = 3000, print_cost=False, loss="crossentropy"):
    """
    Implements a L-layer neural network: [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID.
    
    Arguments:
    X -- data, numpy array of shape (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if cat, 1 if non-cat), of shape (1, number of examples)
    layers_dims -- list containing the input size and each layer size, of length (number of layers + 1).
    learning_rate -- learning rate of the gradient descent update rule
    num_iterations -- number of iterations of the optimization loop
    print_cost -- if True, it prints the cost every 100 steps
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """

    np.random.seed(1)
    costs = []                         # keep track of cost
    
    parameters = initialize_parameters_deep(layers_dims)
    
    # Loop (gradient descent)
    for i in range(0, num_iterations):

        AL, caches = L_model_forward(X, parameters)
        
        # Compute cost.
        cost = compute_cost(AL, Y, loss=loss)
    
        # Backward propagation.
        grads = L_model_backward(AL, Y, caches, loss=loss)
 
        # Update parameters.
        parameters = update_parameters(parameters, grads, learning_rate)
                
        # Print the cost every 100 training example
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
        if print_cost and i % 100 == 0:
            costs.append(cost)
            
    # plot the cost
    plt.plot(np.squeeze(costs))
    plt.ylabel('cost')
    plt.xlabel('iterations (per hundreds)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    
    return parameters

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
def load_data():
  train_dataset = h5py.File("/content/drive/My Drive/datasets/train_catvnoncat.h5", "r")
  train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
  train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

  test_dataset = h5py.File("/content/drive/My Drive/datasets/test_catvnoncat.h5", "r")
  test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
  test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

  classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
  train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
  test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
  return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1).T   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1).T

# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.
test_x = test_x_flatten/255.

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
# Out:
# train_x's shape: (12288, 209)
# test_x's shape: (12288, 50)

# %%
layers_dims = [train_x.shape[0], 20, 7, 5, 1]

parameters = train_model(train_x, train_y, layers_dims, num_iterations = 2000, print_cost = True, loss="crossentropy")
# Out:
# Cost after iteration 0: 0.771749
# Cost after iteration 100: 0.672053
# Cost after iteration 200: 0.648263
# Cost after iteration 300: 0.611507
# Cost after iteration 400: 0.567047
# Cost after iteration 500: 0.540138
# Cost after iteration 600: 0.527930
# Cost after iteration 700: 0.465477
# Cost after iteration 800: 0.369126
# Cost after iteration 900: 0.391747
# Cost after iteration 1000: 0.315187
# Cost after iteration 1100: 0.272700
# Cost after iteration 1200: 0.237419
# Cost after iteration 1300: 0.199601
# Cost after iteration 1400: 0.189263
# Cost after iteration 1500: 0.161189
# Cost after iteration 1600: 0.148214
# Cost after iteration 1700: 0.137775
# Cost after iteration 1800: 0.129740
# Cost after iteration 1900: 0.121225

# %%
pred_train = predict(train_x, train_y, parameters)
# Out:
# Accuracy: 0.9808612440191385

# %%
pred_test = predict(test_x, test_y, parameters)
# Out:
# Accuracy: 0.8

# %%
print_mislabeled_images(classes, test_x, test_y, pred_test)

# %%
mse_X = np.random.randint(0,high=50, size=(1,500))
mse_X_scaled = mse_X/100

mse_Y = mse_X+mse_X
mse_Y_scaled = mse_Y/100

# %%
mse_X_train = mse_X_scaled[0:400]
mse_X_test = mse_X_scaled[400:]
mse_Y_train = mse_Y_scaled[0:400]
mse_Y_test = mse_Y_scaled[400:]

layers_dims_mse = [1,5,4,1]

# %%
parameters = train_model(mse_X_train, mse_Y_train, layers_dims_mse, num_iterations = 50000, print_cost = True, loss="mse", learning_rate = 0.001)
# Out:
# Cost after iteration 0: 0.081022
# Cost after iteration 100: 0.080942
# Cost after iteration 200: 0.080861
# Cost after iteration 300: 0.080781
# Cost after iteration 400: 0.080701
# Cost after iteration 500: 0.080622
# Cost after iteration 600: 0.080542
# Cost after iteration 700: 0.080463
# Cost after iteration 800: 0.080382
# Cost after iteration 900: 0.080301
# Cost after iteration 1000: 0.080221
# Cost after iteration 1100: 0.080140
# Cost after iteration 1200: 0.080060
# Cost after iteration 1300: 0.079980
# Cost after iteration 1400: 0.079900
# Cost after iteration 1500: 0.079820
# Cost after iteration 1600: 0.079741
# Cost after iteration 1700: 0.079661
# Cost after iteration 1800: 0.079582
# Cost after iteration 1900: 0.079502
# Cost after iteration 2000: 0.079423
# Cost after iteration 2100: 0.079344
# Cost after iteration 2200: 0.079265
# Cost after iteration 2300: 0.079185
# Cost after iteration 2400: 0.079105
# Cost after iteration 2500: 0.079026
# Cost after iteration 2600: 0.078946
# Cost after iteration 2700: 0.078866
# Cost after iteration 2800: 0.078787
# Cost after iteration 2900: 0.078708
# Cost after iteration 3000: 0.078628
# Cost after iteration 3100: 0.078549
# Cost after iteration 3200: 0.078470
# Cost after iteration 3300: 0.078390
# Cost after iteration 3400: 0.078309
# Cost after iteration 3500: 0.078227
# Cost after iteration 3600: 0.078145
# Cost after iteration 3700: 0.078064
# Cost after iteration 3800: 0.077982
# Cost after iteration 3900: 0.077901
# Cost after iteration 4000: 0.077819
# Cost after iteration 4100: 0.077735
# Cost after iteration 4200: 0.077649
# Cost after iteration 4300: 0.077563
# Cost after iteration 4400: 0.077477
# Cost after iteration 4500: 0.077391
# Cost after iteration 4600: 0.077303
# Cost after iteration 4700: 0.077211
# Cost after iteration 4800: 0.077119
# Cost after iteration 4900: 0.077027
# Cost after iteration 5000: 0.076934
# Cost after iteration 5100: 0.076838
# Cost after iteration 5200: 0.076742
# Cost after iteration 5300: 0.076647
# Cost after iteration 5400: 0.076546
# Cost after iteration 5500: 0.076444
# Cost after iteration 5600: 0.076341
# Cost after iteration 5700: 0.076234
# Cost after iteration 5800: 0.076124
# Cost after iteration 5900: 0.076015
# Cost after iteration 6000: 0.075901
# Cost after iteration 6100: 0.075786
# Cost after iteration 6200: 0.075668
# Cost after iteration 6300: 0.075545
# Cost after iteration 6400: 0.075422
# Cost after iteration 6500: 0.075292
# Cost after iteration 6600: 0.075162
# Cost after iteration 6700: 0.075028
# Cost after iteration 6800: 0.074894
# Cost after iteration 6900: 0.074755
# Cost after iteration 7000: 0.074615
# Cost after iteration 7100: 0.074467
# Cost after iteration 7200: 0.074318
# Cost after iteration 7300: 0.074164
# Cost after iteration 7400: 0.074008
# Cost after iteration 7500: 0.073845
# Cost after iteration 7600: 0.073681
# Cost after iteration 7700: 0.073515
# Cost after iteration 7800: 0.073345
# Cost after iteration 7900: 0.073174
# Cost after iteration 8000: 0.072996
# Cost after iteration 8100: 0.072817
# Cost after iteration 8200: 0.072638
# Cost after iteration 8300: 0.072456
# Cost after iteration 8400: 0.072271
# Cost after iteration 8500: 0.072084
# Cost after iteration 8600: 0.071897
# Cost after iteration 8700: 0.071707
# Cost after iteration 8800: 0.071517
# Cost after iteration 8900: 0.071325
# Cost after iteration 9000: 0.071133
# Cost after iteration 9100: 0.070942
# Cost after iteration 9200: 0.070750
# Cost after iteration 9300: 0.070560
# Cost after iteration 9400: 0.070371
# Cost after iteration 9500: 0.070186
# Cost after iteration 9600: 0.070004
# Cost after iteration 9700: 0.069824
# Cost after iteration 9800: 0.069645
# Cost after iteration 9900: 0.069472
# Cost after iteration 10000: 0.069299
# Cost after iteration 10100: 0.069128
# Cost after iteration 10200: 0.068961
# Cost after iteration 10300: 0.068796
# Cost after iteration 10400: 0.068633
# Cost after iteration 10500: 0.068473
# Cost after iteration 10600: 0.068317
# Cost after iteration 10700: 0.068164
# Cost after iteration 10800: 0.068013
# Cost after iteration 10900: 0.067862
# Cost after iteration 11000: 0.067712
# Cost after iteration 11100: 0.067564
# Cost after iteration 11200: 0.067420
# Cost after iteration 11300: 0.067276
# Cost after iteration 11400: 0.067137
# Cost after iteration 11500: 0.066997
# Cost after iteration 11600: 0.066861
# Cost after iteration 11700: 0.066727
# Cost after iteration 11800: 0.066593
# Cost after iteration 11900: 0.066461
# Cost after iteration 12000: 0.066329
# Cost after iteration 12100: 0.066197
# Cost after iteration 12200: 0.066067
# Cost after iteration 12300: 0.065943
# Cost after iteration 12400: 0.065819
# Cost after iteration 12500: 0.065694
# Cost after iteration 12600: 0.065568
# Cost after iteration 12700: 0.065443
# Cost after iteration 12800: 0.065319
# Cost after iteration 12900: 0.065195
# Cost after iteration 13000: 0.065071
# Cost after iteration 13100: 0.064947
# Cost after iteration 13200: 0.064822
# Cost after iteration 13300: 0.064697
# Cost after iteration 13400: 0.064572
# Cost after iteration 13500: 0.064446
# Cost after iteration 13600: 0.064320
# Cost after iteration 13700: 0.064195
# Cost after iteration 13800: 0.064069
# Cost after iteration 13900: 0.063942
# Cost after iteration 14000: 0.063816
# Cost after iteration 14100: 0.063688
# Cost after iteration 14200: 0.063561
# Cost after iteration 14300: 0.063433
# Cost after iteration 14400: 0.063305
# Cost after iteration 14500: 0.063177
# Cost after iteration 14600: 0.063048
# Cost after iteration 14700: 0.062919
# Cost after iteration 14800: 0.062790
# Cost after iteration 14900: 0.062662
# Cost after iteration 15000: 0.062533
# Cost after iteration 15100: 0.062404
# Cost after iteration 15200: 0.062275
# Cost after iteration 15300: 0.062145
# Cost after iteration 15400: 0.062016
# Cost after iteration 15500: 0.061885
# Cost after iteration 15600: 0.061755
# Cost after iteration 15700: 0.061624
# Cost after iteration 15800: 0.061493
# Cost after iteration 15900: 0.061361
# Cost after iteration 16000: 0.061230
# Cost after iteration 16100: 0.061097
# Cost after iteration 16200: 0.060965
# Cost after iteration 16300: 0.060832
# Cost after iteration 16400: 0.060699
# Cost after iteration 16500: 0.060565
# Cost after iteration 16600: 0.060432
# Cost after iteration 16700: 0.060298
# Cost after iteration 16800: 0.060163
# Cost after iteration 16900: 0.060028
# Cost after iteration 17000: 0.059893
# Cost after iteration 17100: 0.059758
# Cost after iteration 17200: 0.059622
# Cost after iteration 17300: 0.059486
# Cost after iteration 17400: 0.059350
# Cost after iteration 17500: 0.059213
# Cost after iteration 17600: 0.059076
# Cost after iteration 17700: 0.058939
# Cost after iteration 17800: 0.058801
# Cost after iteration 17900: 0.058663
# Cost after iteration 18000: 0.058525
# Cost after iteration 18100: 0.058387
# Cost after iteration 18200: 0.058248
# Cost after iteration 18300: 0.058109
# Cost after iteration 18400: 0.057970
# Cost after iteration 18500: 0.057830
# Cost after iteration 18600: 0.057689
# Cost after iteration 18700: 0.057549
# Cost after iteration 18800: 0.057408
# Cost after iteration 18900: 0.057267
# Cost after iteration 19000: 0.057125
# Cost after iteration 19100: 0.056983
# Cost after iteration 19200: 0.056840
# Cost after iteration 19300: 0.056698
# Cost after iteration 19400: 0.056555
# Cost after iteration 19500: 0.056412
# Cost after iteration 19600: 0.056268
# Cost after iteration 19700: 0.056124
# Cost after iteration 19800: 0.055980
# Cost after iteration 19900: 0.055836
# Cost after iteration 20000: 0.055691
# Cost after iteration 20100: 0.055546
# Cost after iteration 20200: 0.055401
# Cost after iteration 20300: 0.055255
# Cost after iteration 20400: 0.055109
# Cost after iteration 20500: 0.054962
# Cost after iteration 20600: 0.054816
# Cost after iteration 20700: 0.054669
# Cost after iteration 20800: 0.054521
# Cost after iteration 20900: 0.054374
# Cost after iteration 21000: 0.054226
# Cost after iteration 21100: 0.054078
# Cost after iteration 21200: 0.053929
# Cost after iteration 21300: 0.053780
# Cost after iteration 21400: 0.053631
# Cost after iteration 21500: 0.053481
# Cost after iteration 21600: 0.053331
# Cost after iteration 21700: 0.053181
# Cost after iteration 21800: 0.053031
# Cost after iteration 21900: 0.052880
# Cost after iteration 22000: 0.052728
# Cost after iteration 22100: 0.052577
# Cost after iteration 22200: 0.052425
# Cost after iteration 22300: 0.052273
# Cost after iteration 22400: 0.052120
# Cost after iteration 22500: 0.051967
# Cost after iteration 22600: 0.051815
# Cost after iteration 22700: 0.051662
# Cost after iteration 22800: 0.051509
# Cost after iteration 22900: 0.051355
# Cost after iteration 23000: 0.051201
# Cost after iteration 23100: 0.051047
# Cost after iteration 23200: 0.050893
# Cost after iteration 23300: 0.050738
# Cost after iteration 23400: 0.050583
# Cost after iteration 23500: 0.050428
# Cost after iteration 23600: 0.050272
# Cost after iteration 23700: 0.050116
# Cost after iteration 23800: 0.049959
# Cost after iteration 23900: 0.049803
# Cost after iteration 24000: 0.049646
# Cost after iteration 24100: 0.049489
# Cost after iteration 24200: 0.049331
# Cost after iteration 24300: 0.049173
# Cost after iteration 24400: 0.049015
# Cost after iteration 24500: 0.048857
# Cost after iteration 24600: 0.048699
# Cost after iteration 24700: 0.048540
# Cost after iteration 24800: 0.048381
# Cost after iteration 24900: 0.048222
# Cost after iteration 25000: 0.048062
# Cost after iteration 25100: 0.047903
# Cost after iteration 25200: 0.047743
# Cost after iteration 25300: 0.047582
# Cost after iteration 25400: 0.047422
# Cost after iteration 25500: 0.047261
# Cost after iteration 25600: 0.047100
# Cost after iteration 25700: 0.046939
# Cost after iteration 25800: 0.046777
# Cost after iteration 25900: 0.046615
# Cost after iteration 26000: 0.046453
# Cost after iteration 26100: 0.046291
# Cost after iteration 26200: 0.046129
# Cost after iteration 26300: 0.045966
# Cost after iteration 26400: 0.045803
# Cost after iteration 26500: 0.045640
# Cost after iteration 26600: 0.045477
# Cost after iteration 26700: 0.045314
# Cost after iteration 26800: 0.045150
# Cost after iteration 26900: 0.044986
# Cost after iteration 27000: 0.044822
# Cost after iteration 27100: 0.044658
# Cost after iteration 27200: 0.044493
# Cost after iteration 27300: 0.044329
# Cost after iteration 27400: 0.044164
# Cost after iteration 27500: 0.043999
# Cost after iteration 27600: 0.043834
# Cost after iteration 27700: 0.043669
# Cost after iteration 27800: 0.043504
# Cost after iteration 27900: 0.043338
# Cost after iteration 28000: 0.043173
# Cost after iteration 28100: 0.043007
# Cost after iteration 28200: 0.042841
# Cost after iteration 28300: 0.042675
# Cost after iteration 28400: 0.042509
# Cost after iteration 28500: 0.042343
# Cost after iteration 28600: 0.042177
# Cost after iteration 28700: 0.042011
# Cost after iteration 28800: 0.041844
# Cost after iteration 28900: 0.041678
# Cost after iteration 29000: 0.041511
# Cost after iteration 29100: 0.041345
# Cost after iteration 29200: 0.041178
# Cost after iteration 29300: 0.041011
# Cost after iteration 29400: 0.040844
# Cost after iteration 29500: 0.040677
# Cost after iteration 29600: 0.040510
# Cost after iteration 29700: 0.040343
# Cost after iteration 29800: 0.040176
# Cost after iteration 29900: 0.040009
# Cost after iteration 30000: 0.039841
# Cost after iteration 30100: 0.039674
# Cost after iteration 30200: 0.039507
# Cost after iteration 30300: 0.039339
# Cost after iteration 30400: 0.039172
# Cost after iteration 30500: 0.039005
# Cost after iteration 30600: 0.038837
# Cost after iteration 30700: 0.038670
# Cost after iteration 30800: 0.038502
# Cost after iteration 30900: 0.038335
# Cost after iteration 31000: 0.038168
# Cost after iteration 31100: 0.038000
# Cost after iteration 31200: 0.037833
# Cost after iteration 31300: 0.037666
# Cost after iteration 31400: 0.037498
# Cost after iteration 31500: 0.037331
# Cost after iteration 31600: 0.037164
# Cost after iteration 31700: 0.036997
# Cost after iteration 31800: 0.036830
# Cost after iteration 31900: 0.036663
# Cost after iteration 32000: 0.036497
# Cost after iteration 32100: 0.036330
# Cost after iteration 32200: 0.036163
# Cost after iteration 32300: 0.035997
# Cost after iteration 32400: 0.035830
# Cost after iteration 32500: 0.035664
# Cost after iteration 32600: 0.035498
# Cost after iteration 32700: 0.035332
# Cost after iteration 32800: 0.035166
# Cost after iteration 32900: 0.035000
# Cost after iteration 33000: 0.034834
# Cost after iteration 33100: 0.034668
# Cost after iteration 33200: 0.034503
# Cost after iteration 33300: 0.034338
# Cost after iteration 33400: 0.034172
# Cost after iteration 33500: 0.034008
# Cost after iteration 33600: 0.033845
# Cost after iteration 33700: 0.033682
# Cost after iteration 33800: 0.033520
# Cost after iteration 33900: 0.033358
# Cost after iteration 34000: 0.033196
# Cost after iteration 34100: 0.033034
# Cost after iteration 34200: 0.032872
# Cost after iteration 34300: 0.032711
# Cost after iteration 34400: 0.032550
# Cost after iteration 34500: 0.032390
# Cost after iteration 34600: 0.032229
# Cost after iteration 34700: 0.032069
# Cost after iteration 34800: 0.031910
# Cost after iteration 34900: 0.031750
# Cost after iteration 35000: 0.031591
# Cost after iteration 35100: 0.031432
# Cost after iteration 35200: 0.031274
# Cost after iteration 35300: 0.031115
# Cost after iteration 35400: 0.030958
# Cost after iteration 35500: 0.030800
# Cost after iteration 35600: 0.030643
# Cost after iteration 35700: 0.030486
# Cost after iteration 35800: 0.030329
# Cost after iteration 35900: 0.030173
# Cost after iteration 36000: 0.030017
# Cost after iteration 36100: 0.029862
# Cost after iteration 36200: 0.029706
# Cost after iteration 36300: 0.029552
# Cost after iteration 36400: 0.029397
# Cost after iteration 36500: 0.029243
# Cost after iteration 36600: 0.029089
# Cost after iteration 36700: 0.028936
# Cost after iteration 36800: 0.028783
# Cost after iteration 36900: 0.028630
# Cost after iteration 37000: 0.028478
# Cost after iteration 37100: 0.028326
# Cost after iteration 37200: 0.028174
# Cost after iteration 37300: 0.028023
# Cost after iteration 37400: 0.027872
# Cost after iteration 37500: 0.027722
# Cost after iteration 37600: 0.027572
# Cost after iteration 37700: 0.027422
# Cost after iteration 37800: 0.027273
# Cost after iteration 37900: 0.027124
# Cost after iteration 38000: 0.026976
# Cost after iteration 38100: 0.026828
# Cost after iteration 38200: 0.026681
# Cost after iteration 38300: 0.026534
# Cost after iteration 38400: 0.026387
# Cost after iteration 38500: 0.026241
# Cost after iteration 38600: 0.026095
# Cost after iteration 38700: 0.025950
# Cost after iteration 38800: 0.025805
# Cost after iteration 38900: 0.025660
# Cost after iteration 39000: 0.025516
# Cost after iteration 39100: 0.025373
# Cost after iteration 39200: 0.025230
# Cost after iteration 39300: 0.025087
# Cost after iteration 39400: 0.024945
# Cost after iteration 39500: 0.024804
# Cost after iteration 39600: 0.024663
# Cost after iteration 39700: 0.024523
# Cost after iteration 39800: 0.024383
# Cost after iteration 39900: 0.024244
# Cost after iteration 40000: 0.024105
# Cost after iteration 40100: 0.023967
# Cost after iteration 40200: 0.023829
# Cost after iteration 40300: 0.023692
# Cost after iteration 40400: 0.023555
# Cost after iteration 40500: 0.023418
# Cost after iteration 40600: 0.023283
# Cost after iteration 40700: 0.023147
# Cost after iteration 40800: 0.023012
# Cost after iteration 40900: 0.022878
# Cost after iteration 41000: 0.022744
# Cost after iteration 41100: 0.022611
# Cost after iteration 41200: 0.022478
# Cost after iteration 41300: 0.022346
# Cost after iteration 41400: 0.022214
# Cost after iteration 41500: 0.022083
# Cost after iteration 41600: 0.021952
# Cost after iteration 41700: 0.021822
# Cost after iteration 41800: 0.021693
# Cost after iteration 41900: 0.021564
# Cost after iteration 42000: 0.021435
# Cost after iteration 42100: 0.021307
# Cost after iteration 42200: 0.021180
# Cost after iteration 42300: 0.021053
# Cost after iteration 42400: 0.020926
# Cost after iteration 42500: 0.020800
# Cost after iteration 42600: 0.020675
# Cost after iteration 42700: 0.020550
# Cost after iteration 42800: 0.020426
# Cost after iteration 42900: 0.020302
# Cost after iteration 43000: 0.020179
# Cost after iteration 43100: 0.020057
# Cost after iteration 43200: 0.019935
# Cost after iteration 43300: 0.019813
# Cost after iteration 43400: 0.019692
# Cost after iteration 43500: 0.019572
# Cost after iteration 43600: 0.019452
# Cost after iteration 43700: 0.019333
# Cost after iteration 43800: 0.019214
# Cost after iteration 43900: 0.019096
# Cost after iteration 44000: 0.018978
# Cost after iteration 44100: 0.018861
# Cost after iteration 44200: 0.018745
# Cost after iteration 44300: 0.018629
# Cost after iteration 44400: 0.018513
# Cost after iteration 44500: 0.018398
# Cost after iteration 44600: 0.018284
# Cost after iteration 44700: 0.018171
# Cost after iteration 44800: 0.018058
# Cost after iteration 44900: 0.017945
# Cost after iteration 45000: 0.017833
# Cost after iteration 45100: 0.017722
# Cost after iteration 45200: 0.017611
# Cost after iteration 45300: 0.017501
# Cost after iteration 45400: 0.017392
# Cost after iteration 45500: 0.017283
# Cost after iteration 45600: 0.017174
# Cost after iteration 45700: 0.017066
# Cost after iteration 45800: 0.016959
# Cost after iteration 45900: 0.016852
# Cost after iteration 46000: 0.016746
# Cost after iteration 46100: 0.016640
# Cost after iteration 46200: 0.016535
# Cost after iteration 46300: 0.016431
# Cost after iteration 46400: 0.016327
# Cost after iteration 46500: 0.016224
# Cost after iteration 46600: 0.016121
# Cost after iteration 46700: 0.016019
# Cost after iteration 46800: 0.015917
# Cost after iteration 46900: 0.015816
# Cost after iteration 47000: 0.015715
# Cost after iteration 47100: 0.015615
# Cost after iteration 47200: 0.015516
# Cost after iteration 47300: 0.015417
# Cost after iteration 47400: 0.015319
# Cost after iteration 47500: 0.015221
# Cost after iteration 47600: 0.015124
# Cost after iteration 47700: 0.015027
# Cost after iteration 47800: 0.014931
# Cost after iteration 47900: 0.014835
# Cost after iteration 48000: 0.014740
# Cost after iteration 48100: 0.014646
# Cost after iteration 48200: 0.014552
# Cost after iteration 48300: 0.014459
# Cost after iteration 48400: 0.014366
# Cost after iteration 48500: 0.014273
# Cost after iteration 48600: 0.014182
# Cost after iteration 48700: 0.014090
# Cost after iteration 48800: 0.014000
# Cost after iteration 48900: 0.013910
# Cost after iteration 49000: 0.013820
# Cost after iteration 49100: 0.013731
# Cost after iteration 49200: 0.013643
# Cost after iteration 49300: 0.013555
# Cost after iteration 49400: 0.013468
# Cost after iteration 49500: 0.013381
# Cost after iteration 49600: 0.013295
# Cost after iteration 49700: 0.013210
# Cost after iteration 49800: 0.013125
# Cost after iteration 49900: 0.013041
