# %% [markdown]
# <a href="https://colab.research.google.com/github/simonme42/ANN_experiments/blob/master/ANN_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ANN from scratch
#
# *   In this notebook, we implement an artificial neural network from scratch.
# *   All we need are a few standard python libraries
# *   At the end we´ll test our ANN implementation on image classification and regression tasks

# %%
import numpy as np
import scipy
import h5py
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # The functions that we need to implement a NN

# %%
def sigmoid(Z):
    """
    Implements the sigmoid activation in numpy
    
    Arguments:
    Z -- numpy array of any shape
    
    Returns:
    A -- output of sigmoid(z), same shape as Z
    cache -- returns Z as well, useful during backpropagation
    """
    
    A = 1/(1+np.exp(-Z))
    cache = Z
    
    return A, cache

def relu(Z):
    """
    Implement the RELU function.

    Arguments:
    Z -- Output of the linear layer, of any shape

    Returns:
    A -- Post-activation parameter, of the same shape as Z
    cache -- a python dictionary containing "A" ; stored for computing the backward pass efficiently
    """
    
    A = np.maximum(0,Z)
    
    assert(A.shape == Z.shape)
    
    cache = Z 
    return A, cache


def relu_backward(dA, cache):
    """
    Implement the backward propagation for a single RELU unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the cost with respect to Z
    """
    
    Z = cache
    dZ = np.array(dA, copy=True) # just converting dz to a correct object.
    
    # When z <= 0, you should set dz to 0 as well. 
    dZ[Z <= 0] = 0
    
    assert (dZ.shape == Z.shape)
    
    return dZ

def sigmoid_backward(dA, cache):
    """
    Implement the backward propagation for a single SIGMOID unit.

    Arguments:
    dA -- post-activation gradient, of any shape
    cache -- 'Z' where we store for computing backward propagation efficiently

    Returns:
    dZ -- Gradient of the cost with respect to Z
    """
    
    Z = cache
    
    s = 1/(1+np.exp(-Z))
    dZ = dA * s * (1-s)
    
    assert (dZ.shape == Z.shape)
    
    return dZ



def initialize_parameters_deep(layer_dims):
    """
    Arguments:
    layer_dims -- python array (list) containing the dimensions of each layer in our network
    
    Returns:
    parameters -- python dictionary containing your parameters "W1", "b1", ..., "WL", "bL":
                    Wl -- weight matrix of shape (layer_dims[l], layer_dims[l-1])
                    bl -- bias vector of shape (layer_dims[l], 1)
    """
    
    #np.random.seed(1)
    parameters = {}
    L = len(layer_dims)            # number of layers in the network

    for l in range(1, L):
        parameters['W' + str(l)] = np.random.randn(layer_dims[l], layer_dims[l-1]) / np.sqrt(layer_dims[l-1]) #*0.01
        parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))
        
        assert(parameters['W' + str(l)].shape == (layer_dims[l], layer_dims[l-1]))
        assert(parameters['b' + str(l)].shape == (layer_dims[l], 1))

        
    return parameters

def linear_forward(A, W, b):
    """
    Implement the linear part of a layer's forward propagation.

    Arguments:
    A -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)

    Returns:
    Z -- the input of the activation function, also called pre-activation parameter 
    cache -- a python dictionary containing "A", "W" and "b" ; stored for computing the backward pass efficiently
    """
    
    Z = np.dot(W,A)+b
    
    assert(Z.shape == (W.shape[0], A.shape[1]))
    cache = (A, W, b)
    
    return Z, cache

def linear_activation_forward(A_prev, W, b, activation):
    """
    Implement the forward propagation for the LINEAR->ACTIVATION layer

    Arguments:
    A_prev -- activations from previous layer (or input data): (size of previous layer, number of examples)
    W -- weights matrix: numpy array of shape (size of current layer, size of previous layer)
    b -- bias vector, numpy array of shape (size of the current layer, 1)
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"

    Returns:
    A -- the output of the activation function, also called the post-activation value 
    cache -- a python dictionary containing "linear_cache" and "activation_cache";
             stored for computing the backward pass efficiently
    """
    
    if activation == "sigmoid":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = sigmoid(Z)
    
    elif activation == "relu":
        # Inputs: "A_prev, W, b". Outputs: "A, activation_cache".
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = relu(Z)
    
    assert (A.shape == (W.shape[0], A_prev.shape[1]))
    cache = (linear_cache, activation_cache)

    return A, cache

def L_model_forward(X, parameters):
    """
    Implement forward propagation for the [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID computation
    
    Arguments:
    X -- data, numpy array of shape (input size, number of examples)
    parameters -- output of initialize_parameters_deep()
    
    Returns:
    AL -- last post-activation value
    caches -- list of caches containing:
                every cache of linear_relu_forward() (there are L-1 of them, indexed from 0 to L-2)
                the cache of linear_sigmoid_forward() (there is one, indexed L-1)
    """

    caches = []
    A = X
    L = len(parameters) // 2                  # number of layers in the neural network
    
    # Implement [LINEAR -> RELU]*(L-1). Add "cache" to the "caches" list.
    for l in range(1, L):
        A_prev = A 
        A, cache = linear_activation_forward(A_prev, parameters["W"+str(l)], parameters["b"+str(l)], activation="relu")
        caches.append(cache)
    
    # Implement LINEAR -> SIGMOID. Add "cache" to the "caches" list.
    AL, cache = linear_activation_forward(A, parameters["W"+str(L)], parameters["b"+str(L)], activation="sigmoid")
    caches.append(cache)
    
    assert(AL.shape == (1,X.shape[1]))
            
    return AL, caches

def compute_cost(AL, Y, loss="crossentropy"):
    """
    Implement the cost function

    Arguments:
    AL -- probability vector corresponding to your label predictions, shape (1, number of examples)
    Y -- true "label" vector (for example: containing 0 if non-cat, 1 if cat), shape (1, number of examples)

    Returns:
    cost -- cross-entropy or mse cost
    """
    
    m = Y.shape[1]

    # Compute loss from aL and y.
    if loss == "crossentropy":
      cost = (1./m) * (-np.dot(Y,np.log(AL).T) - np.dot(1-Y, np.log(1-AL).T))
    
    elif loss == "mse":
      cost = (1./m) * (np.sum((AL-Y)**2,axis=1, keepdims=True))
    
    cost = np.squeeze(cost)      # To make sure the cost's shape is what we expect (e.g. this turns [[17]] into 17).
    assert(cost.shape == ())
    
    return cost

def linear_backward(dZ, cache):
    """
    Implement the linear portion of backward propagation for a single layer (layer l)

    Arguments:
    dZ -- Gradient of the cost with respect to the linear output (of current layer l)
    cache -- tuple of values (A_prev, W, b) coming from the forward propagation in the current layer

    Returns:
    dA_prev -- Gradient of the cost with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the cost with respect to W (current layer l), same shape as W
    db -- Gradient of the cost with respect to b (current layer l), same shape as b
    """
    A_prev, W, b = cache
    m = A_prev.shape[1]

    dW = 1./m * np.dot(dZ,A_prev.T)
    db = 1./m * np.sum(dZ, axis = 1, keepdims = True)
    dA_prev = np.dot(W.T,dZ)
    
    assert (dA_prev.shape == A_prev.shape)
    assert (dW.shape == W.shape)
    assert (db.shape == b.shape)
    
    return dA_prev, dW, db

def linear_activation_backward(dA, cache, activation):
    """
    Implement the backward propagation for the LINEAR->ACTIVATION layer.
    
    Arguments:
    dA -- post-activation gradient for current layer l 
    cache -- tuple of values (linear_cache, activation_cache) we store for computing backward propagation efficiently
    activation -- the activation to be used in this layer, stored as a text string: "sigmoid" or "relu"
    
    Returns:
    dA_prev -- Gradient of the cost with respect to the activation (of the previous layer l-1), same shape as A_prev
    dW -- Gradient of the cost with respect to W (current layer l), same shape as W
    db -- Gradient of the cost with respect to b (current layer l), same shape as b
    """
    linear_cache, activation_cache = cache
    
    if activation == "relu":
        dZ = relu_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
        
    elif activation == "sigmoid":
        dZ = sigmoid_backward(dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
    
    return dA_prev, dW, db

def L_model_backward(AL, Y, caches, loss="crossentropy"):
    """
    Implement the backward propagation for the [LINEAR->RELU] * (L-1) -> LINEAR -> SIGMOID group
    
    Arguments:
    AL -- probability vector, output of the forward propagation (L_model_forward())
    Y -- true "label" vector (containing 0 if non-cat, 1 if cat)
    caches -- list of caches containing:
                every cache of linear_activation_forward() with "relu" (there are (L-1) or them, indexes from 0 to L-2)
                the cache of linear_activation_forward() with "sigmoid" (there is one, index L-1)
    
    Returns:
    grads -- A dictionary with the gradients
             grads["dA" + str(l)] = ... 
             grads["dW" + str(l)] = ...
             grads["db" + str(l)] = ... 
    """
    grads = {}
    L = len(caches) # the number of layers
    m = AL.shape[1]
    Y = Y.reshape(AL.shape) # after this line, Y is the same shape as AL
    
    # Initializing the backpropagation

    if loss == "crossentropy":
      dAL = - (np.divide(Y, AL) - np.divide(1 - Y, 1 - AL))
    
    elif loss == "mse":
      dAL = 2*(AL-Y)
    
    # Lth layer (SIGMOID -> LINEAR) gradients. Inputs: "AL, Y, caches". Outputs: "grads["dAL"], grads["dWL"], grads["dbL"]
    current_cache = caches[L-1]
    grads["dA" + str(L-1)], grads["dW" + str(L)], grads["db" + str(L)] = linear_activation_backward(dAL, current_cache, activation = "sigmoid")
    
    for l in reversed(range(L-1)):
        # lth layer: (RELU -> LINEAR) gradients.
        current_cache = caches[l]
        dA_prev_temp, dW_temp, db_temp = linear_activation_backward(grads["dA" + str(l + 1)], current_cache, activation = "relu")
        grads["dA" + str(l)] = dA_prev_temp
        grads["dW" + str(l + 1)] = dW_temp
        grads["db" + str(l + 1)] = db_temp

    return grads

def update_parameters(parameters, grads, learning_rate):
    """
    Update parameters using gradient descent
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    grads -- python dictionary containing your gradients, output of L_model_backward
    
    Returns:
    parameters -- python dictionary containing your updated parameters 
                  parameters["W" + str(l)] = ... 
                  parameters["b" + str(l)] = ...
    """
    
    L = len(parameters) // 2 # number of layers in the neural network

    # Update rule for each parameter. Use a for loop.
    for l in range(L):
        parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate * grads["dW" + str(l+1)]
        parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate * grads["db" + str(l+1)]
        
    return parameters

def predict(X, y, parameters, loss="crossentropy"):
    """
    This function is used to predict the results of a  L-layer neural network.
    
    Arguments:
    X -- data set of examples you would like to label
    parameters -- parameters of the trained model
    
    Returns:
    p -- predictions for the given dataset X
    """
    m = X.shape[1]
    n = len(parameters) // 2 # number of layers in the neural network

    if loss == "crossentropy":
     
      p = np.zeros((1,m))
        
      # Forward propagation
      probas, caches = L_model_forward(X, parameters)
        
      # convert probas to 0/1 predictions
      for i in range(0, probas.shape[1]):
          if probas[0,i] > 0.5:
            p[0,i] = 1
          else:
            p[0,i] = 0
      
      print("Accuracy: "  + str(np.sum((p == y)/m)))

    elif loss == "mse":

      p, caches = L_model_forward(X, parameters)

      print("Accuracy: "  + str((1/m)*np.sum(p-y)**2))
    
    #print results
    #print ("predictions: " + str(p))
    #print ("true labels: " + str(y))
    
    return p

def print_mislabeled_images(classes, X, y, p):
    """
    Plots images where predictions and truth were different.
    X -- dataset
    y -- true labels
    p -- predictions
    """
    a = p + y
    mislabeled_indices = np.asarray(np.where(a == 1))
    plt.rcParams['figure.figsize'] = (40.0, 40.0) # set default size of plots
    num_images = len(mislabeled_indices[0])
    for i in range(num_images):
        index = mislabeled_indices[1][i]
        
        plt.subplot(2, num_images, i + 1)
        plt.imshow(X[:,index].reshape(64,64,3), interpolation='nearest')
        plt.axis('off')
        plt.title("Prediction: " + classes[int(p[0,index])].decode("utf-8") + " \n Class: " + classes[y[0,index]].decode("utf-8"))

def train_model(X, Y, layers_dims, learning_rate = 0.0075, num_iterations = 3000, print_cost=False, loss="crossentropy"):
    """
    Implements a L-layer neural network: [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID.
    
    Arguments:
    X -- data, numpy array of shape (num_px * num_px * 3, number of examples)
    Y -- true "label" vector (containing 0 if cat, 1 if non-cat), of shape (1, number of examples)
    layers_dims -- list containing the input size and each layer size, of length (number of layers + 1).
    learning_rate -- learning rate of the gradient descent update rule
    num_iterations -- number of iterations of the optimization loop
    print_cost -- if True, it prints the cost every 100 steps
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """

    np.random.seed(1)
    costs = []                         # keep track of cost
    
    parameters = initialize_parameters_deep(layers_dims)
    
    # Loop (gradient descent)
    for i in range(0, num_iterations):

        AL, caches = L_model_forward(X, parameters)
        
        # Compute cost.
        cost = compute_cost(AL, Y, loss=loss)
    
        # Backward propagation.
        grads = L_model_backward(AL, Y, caches, loss=loss)
 
        # Update parameters.
        parameters = update_parameters(parameters, grads, learning_rate)
                
        # Print the cost every 100 training example
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
        if print_cost and i % 100 == 0:
            costs.append(cost)
            
    # plot the cost
    plt.plot(np.squeeze(costs))
    plt.ylabel('cost')
    plt.xlabel('iterations (per hundreds)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    
    return parameters

# %% [markdown]
# # Now we train our NN on binary image classification using cat vs noncat

# %%
# !git clone https://github.com/simonme42/ANN_experiments.git
# Out:
# Cloning into 'ANN_experiments'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 66 (delta 30), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (66/66), done.

# %%
def load_data():
  train_dataset = h5py.File("ANN_experiments/datasets/train_catvnoncat.h5", "r")
  train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
  train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

  test_dataset = h5py.File("ANN_experiments/datasets/test_catvnoncat.h5", "r")
  test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
  test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

  classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
  train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
  test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
  return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1).T   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1).T

# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.
test_x = test_x_flatten/255.

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
# Out:
# train_x's shape: (12288, 209)
# test_x's shape: (12288, 50)

# %%
layers_dims = [train_x.shape[0], 20, 7, 5, 1]

parameters = train_model(train_x, train_y, layers_dims, num_iterations = 2000, print_cost = True, loss="crossentropy")
# Out:
# Cost after iteration 0: 0.771749
# Cost after iteration 100: 0.672053
# Cost after iteration 200: 0.648263
# Cost after iteration 300: 0.611507
# Cost after iteration 400: 0.567047
# Cost after iteration 500: 0.540138
# Cost after iteration 600: 0.527930
# Cost after iteration 700: 0.465477
# Cost after iteration 800: 0.369126
# Cost after iteration 900: 0.391747
# Cost after iteration 1000: 0.315187
# Cost after iteration 1100: 0.272700
# Cost after iteration 1200: 0.237419
# Cost after iteration 1300: 0.199601
# Cost after iteration 1400: 0.189263
# Cost after iteration 1500: 0.161189
# Cost after iteration 1600: 0.148214
# Cost after iteration 1700: 0.137775
# Cost after iteration 1800: 0.129740
# Cost after iteration 1900: 0.121225

# %%
pred_train = predict(train_x, train_y, parameters)
pred_test = predict(test_x, test_y, parameters)
# Out:
# Accuracy: 0.9808612440191385
# Accuracy: 0.8

# %%
print_mislabeled_images(classes, test_x, test_y, pred_test)

# %% [markdown]
# ## Now we use our NN implementation for a Regression task (adding 2 numbers)

# %%
def create_mse_data(low, high, m, train_test_split=0.2):

  mse_X = np.random.randint(low,high=high, size=(2,m))
  mse_X_scaled = mse_X/(high*2)

  mse_Y = (mse_X[0,:]+mse_X[0,:]).reshape(1,mse_X.shape[1])
  mse_Y_scaled = mse_Y/(high*2)

  mse_X_train = mse_X_scaled[:,0:int(m*train_test_split)]
  mse_X_test = mse_X_scaled[:,int(m*train_test_split):]
  mse_Y_train = mse_Y_scaled[:,0:int(m*train_test_split)]
  mse_Y_test = mse_Y_scaled[:,int(m*train_test_split):]

  return (mse_X_train,mse_X_test,mse_Y_train,mse_Y_test)


(mse_X_train,mse_X_test,mse_Y_train,mse_Y_test) = create_mse_data(0,50,1000)

layers_dims_mse = [mse_X_train.shape[0],5,4,1]

# %%
parameters = train_model(mse_X_train, mse_Y_train, layers_dims_mse, num_iterations = 50000, print_cost = True, loss="mse", learning_rate = 0.01)
# Out:
# Cost after iteration 0: 0.084143
# Cost after iteration 100: 0.083570
# Cost after iteration 200: 0.082937
# Cost after iteration 300: 0.082182
# Cost after iteration 400: 0.081390
# Cost after iteration 500: 0.080464
# Cost after iteration 600: 0.079667
# Cost after iteration 700: 0.079180
# Cost after iteration 800: 0.078830
# Cost after iteration 900: 0.078543
# Cost after iteration 1000: 0.078275
# Cost after iteration 1100: 0.078005
# Cost after iteration 1200: 0.077732
# Cost after iteration 1300: 0.077454
# Cost after iteration 1400: 0.077171
# Cost after iteration 1500: 0.076889
# Cost after iteration 1600: 0.076608
# Cost after iteration 1700: 0.076323
# Cost after iteration 1800: 0.076027
# Cost after iteration 1900: 0.075722
# Cost after iteration 2000: 0.075410
# Cost after iteration 2100: 0.075089
# Cost after iteration 2200: 0.074757
# Cost after iteration 2300: 0.074411
# Cost after iteration 2400: 0.074061
# Cost after iteration 2500: 0.073701
# Cost after iteration 2600: 0.073330
# Cost after iteration 2700: 0.072948
# Cost after iteration 2800: 0.072551
# Cost after iteration 2900: 0.072143
# Cost after iteration 3000: 0.071720
# Cost after iteration 3100: 0.071281
# Cost after iteration 3200: 0.070830
# Cost after iteration 3300: 0.070364
# Cost after iteration 3400: 0.069882
# Cost after iteration 3500: 0.069383
# Cost after iteration 3600: 0.068867
# Cost after iteration 3700: 0.068333
# Cost after iteration 3800: 0.067779
# Cost after iteration 3900: 0.067205
# Cost after iteration 4000: 0.066610
# Cost after iteration 4100: 0.065998
# Cost after iteration 4200: 0.065364
# Cost after iteration 4300: 0.064710
# Cost after iteration 4400: 0.064035
# Cost after iteration 4500: 0.063338
# Cost after iteration 4600: 0.062620
# Cost after iteration 4700: 0.061880
# Cost after iteration 4800: 0.061120
# Cost after iteration 4900: 0.060337
# Cost after iteration 5000: 0.059533
# Cost after iteration 5100: 0.058708
# Cost after iteration 5200: 0.057861
# Cost after iteration 5300: 0.056992
# Cost after iteration 5400: 0.056103
# Cost after iteration 5500: 0.055196
# Cost after iteration 5600: 0.054272
# Cost after iteration 5700: 0.053333
# Cost after iteration 5800: 0.052380
# Cost after iteration 5900: 0.051411
# Cost after iteration 6000: 0.050429
# Cost after iteration 6100: 0.049438
# Cost after iteration 6200: 0.048439
# Cost after iteration 6300: 0.047433
# Cost after iteration 6400: 0.046427
# Cost after iteration 6500: 0.045416
# Cost after iteration 6600: 0.044400
# Cost after iteration 6700: 0.043386
# Cost after iteration 6800: 0.042372
# Cost after iteration 6900: 0.041362
# Cost after iteration 7000: 0.040353
# Cost after iteration 7100: 0.039347
# Cost after iteration 7200: 0.038348
# Cost after iteration 7300: 0.037360
# Cost after iteration 7400: 0.036381
# Cost after iteration 7500: 0.035411
# Cost after iteration 7600: 0.034454
# Cost after iteration 7700: 0.033508
# Cost after iteration 7800: 0.032574
# Cost after iteration 7900: 0.031653
# Cost after iteration 8000: 0.030749
# Cost after iteration 8100: 0.029862
# Cost after iteration 8200: 0.028996
# Cost after iteration 8300: 0.028147
# Cost after iteration 8400: 0.027318
# Cost after iteration 8500: 0.026506
# Cost after iteration 8600: 0.025714
# Cost after iteration 8700: 0.024940
# Cost after iteration 8800: 0.024184
# Cost after iteration 8900: 0.023448
# Cost after iteration 9000: 0.022734
# Cost after iteration 9100: 0.022040
# Cost after iteration 9200: 0.021366
# Cost after iteration 9300: 0.020713
# Cost after iteration 9400: 0.020078
# Cost after iteration 9500: 0.019463
# Cost after iteration 9600: 0.018867
# Cost after iteration 9700: 0.018290
# Cost after iteration 9800: 0.017731
# Cost after iteration 9900: 0.017191
# Cost after iteration 10000: 0.016670
# Cost after iteration 10100: 0.016166
# Cost after iteration 10200: 0.015680
# Cost after iteration 10300: 0.015211
# Cost after iteration 10400: 0.014761
# Cost after iteration 10500: 0.014326
# Cost after iteration 10600: 0.013908
# Cost after iteration 10700: 0.013505
# Cost after iteration 10800: 0.013116
# Cost after iteration 10900: 0.012742
# Cost after iteration 11000: 0.012381
# Cost after iteration 11100: 0.012034
# Cost after iteration 11200: 0.011700
# Cost after iteration 11300: 0.011377
# Cost after iteration 11400: 0.011067
# Cost after iteration 11500: 0.010769
# Cost after iteration 11600: 0.010482
# Cost after iteration 11700: 0.010206
# Cost after iteration 11800: 0.009941
# Cost after iteration 11900: 0.009686
# Cost after iteration 12000: 0.009440
# Cost after iteration 12100: 0.009204
# Cost after iteration 12200: 0.008976
# Cost after iteration 12300: 0.008758
# Cost after iteration 12400: 0.008549
# Cost after iteration 12500: 0.008347
# Cost after iteration 12600: 0.008153
# Cost after iteration 12700: 0.007966
# Cost after iteration 12800: 0.007786
# Cost after iteration 12900: 0.007612
# Cost after iteration 13000: 0.007445
# Cost after iteration 13100: 0.007285
# Cost after iteration 13200: 0.007130
# Cost after iteration 13300: 0.006980
# Cost after iteration 13400: 0.006836
# Cost after iteration 13500: 0.006697
# Cost after iteration 13600: 0.006563
# Cost after iteration 13700: 0.006434
# Cost after iteration 13800: 0.006309
# Cost after iteration 13900: 0.006188
# Cost after iteration 14000: 0.006072
# Cost after iteration 14100: 0.005960
# Cost after iteration 14200: 0.005851
# Cost after iteration 14300: 0.005746
# Cost after iteration 14400: 0.005645
# Cost after iteration 14500: 0.005547
# Cost after iteration 14600: 0.005452
# Cost after iteration 14700: 0.005360
# Cost after iteration 14800: 0.005271
# Cost after iteration 14900: 0.005185
# Cost after iteration 15000: 0.005101
# Cost after iteration 15100: 0.005021
# Cost after iteration 15200: 0.004943
# Cost after iteration 15300: 0.004867
# Cost after iteration 15400: 0.004794
# Cost after iteration 15500: 0.004723
# Cost after iteration 15600: 0.004654
# Cost after iteration 15700: 0.004588
# Cost after iteration 15800: 0.004523
# Cost after iteration 15900: 0.004460
# Cost after iteration 16000: 0.004399
# Cost after iteration 16100: 0.004339
# Cost after iteration 16200: 0.004281
# Cost after iteration 16300: 0.004225
# Cost after iteration 16400: 0.004170
# Cost after iteration 16500: 0.004117
# Cost after iteration 16600: 0.004065
# Cost after iteration 16700: 0.004015
# Cost after iteration 16800: 0.003966
# Cost after iteration 16900: 0.003918
# Cost after iteration 17000: 0.003872
# Cost after iteration 17100: 0.003826
# Cost after iteration 17200: 0.003782
# Cost after iteration 17300: 0.003739
# Cost after iteration 17400: 0.003697
# Cost after iteration 17500: 0.003656
# Cost after iteration 17600: 0.003616
# Cost after iteration 17700: 0.003577
# Cost after iteration 17800: 0.003538
# Cost after iteration 17900: 0.003501
# Cost after iteration 18000: 0.003465
# Cost after iteration 18100: 0.003429
# Cost after iteration 18200: 0.003394
# Cost after iteration 18300: 0.003360
# Cost after iteration 18400: 0.003327
# Cost after iteration 18500: 0.003294
# Cost after iteration 18600: 0.003263
# Cost after iteration 18700: 0.003231
# Cost after iteration 18800: 0.003201
# Cost after iteration 18900: 0.003171
# Cost after iteration 19000: 0.003142
# Cost after iteration 19100: 0.003114
# Cost after iteration 19200: 0.003086
# Cost after iteration 19300: 0.003058
# Cost after iteration 19400: 0.003031
# Cost after iteration 19500: 0.003005
# Cost after iteration 19600: 0.002979
# Cost after iteration 19700: 0.002954
# Cost after iteration 19800: 0.002929
# Cost after iteration 19900: 0.002905
# Cost after iteration 20000: 0.002881
# Cost after iteration 20100: 0.002858
# Cost after iteration 20200: 0.002835
# Cost after iteration 20300: 0.002813
# Cost after iteration 20400: 0.002791
# Cost after iteration 20500: 0.002769
# Cost after iteration 20600: 0.002748
# Cost after iteration 20700: 0.002727
# Cost after iteration 20800: 0.002706
# Cost after iteration 20900: 0.002686
# Cost after iteration 21000: 0.002666
# Cost after iteration 21100: 0.002646
# Cost after iteration 21200: 0.002627
# Cost after iteration 21300: 0.002608
# Cost after iteration 21400: 0.002590
# Cost after iteration 21500: 0.002571
# Cost after iteration 21600: 0.002553
# Cost after iteration 21700: 0.002535
# Cost after iteration 21800: 0.002518
# Cost after iteration 21900: 0.002501
# Cost after iteration 22000: 0.002484
# Cost after iteration 22100: 0.002467
# Cost after iteration 22200: 0.002450
# Cost after iteration 22300: 0.002434
# Cost after iteration 22400: 0.002418
# Cost after iteration 22500: 0.002403
# Cost after iteration 22600: 0.002387
# Cost after iteration 22700: 0.002372
# Cost after iteration 22800: 0.002357
# Cost after iteration 22900: 0.002342
# Cost after iteration 23000: 0.002327
# Cost after iteration 23100: 0.002313
# Cost after iteration 23200: 0.002298
# Cost after iteration 23300: 0.002285
# Cost after iteration 23400: 0.002271
# Cost after iteration 23500: 0.002258
# Cost after iteration 23600: 0.002245
# Cost after iteration 23700: 0.002232
# Cost after iteration 23800: 0.002219
# Cost after iteration 23900: 0.002207
# Cost after iteration 24000: 0.002195
# Cost after iteration 24100: 0.002183
# Cost after iteration 24200: 0.002171
# Cost after iteration 24300: 0.002159
# Cost after iteration 24400: 0.002147
# Cost after iteration 24500: 0.002136
# Cost after iteration 24600: 0.002124
# Cost after iteration 24700: 0.002113
# Cost after iteration 24800: 0.002102
# Cost after iteration 24900: 0.002091
# Cost after iteration 25000: 0.002080
# Cost after iteration 25100: 0.002070
# Cost after iteration 25200: 0.002059
# Cost after iteration 25300: 0.002049
# Cost after iteration 25400: 0.002039
# Cost after iteration 25500: 0.002029
# Cost after iteration 25600: 0.002019
# Cost after iteration 25700: 0.002010
# Cost after iteration 25800: 0.002000
# Cost after iteration 25900: 0.001991
# Cost after iteration 26000: 0.001981
# Cost after iteration 26100: 0.001972
# Cost after iteration 26200: 0.001963
# Cost after iteration 26300: 0.001954
# Cost after iteration 26400: 0.001945
# Cost after iteration 26500: 0.001937
# Cost after iteration 26600: 0.001928
# Cost after iteration 26700: 0.001920
# Cost after iteration 26800: 0.001911
# Cost after iteration 26900: 0.001903
# Cost after iteration 27000: 0.001895
# Cost after iteration 27100: 0.001887
# Cost after iteration 27200: 0.001878
# Cost after iteration 27300: 0.001871
# Cost after iteration 27400: 0.001863
# Cost after iteration 27500: 0.001855
# Cost after iteration 27600: 0.001847
# Cost after iteration 27700: 0.001840
# Cost after iteration 27800: 0.001832
# Cost after iteration 27900: 0.001825
# Cost after iteration 28000: 0.001817
# Cost after iteration 28100: 0.001810
# Cost after iteration 28200: 0.001803
# Cost after iteration 28300: 0.001796
# Cost after iteration 28400: 0.001789
# Cost after iteration 28500: 0.001782
# Cost after iteration 28600: 0.001775
# Cost after iteration 28700: 0.001768
# Cost after iteration 28800: 0.001761
# Cost after iteration 28900: 0.001754
# Cost after iteration 29000: 0.001748
# Cost after iteration 29100: 0.001741
# Cost after iteration 29200: 0.001735
# Cost after iteration 29300: 0.001728
# Cost after iteration 29400: 0.001722
# Cost after iteration 29500: 0.001716
# Cost after iteration 29600: 0.001709
# Cost after iteration 29700: 0.001703
# Cost after iteration 29800: 0.001697
# Cost after iteration 29900: 0.001691
# Cost after iteration 30000: 0.001685
# Cost after iteration 30100: 0.001680
# Cost after iteration 30200: 0.001674
# Cost after iteration 30300: 0.001668
# Cost after iteration 30400: 0.001663
# Cost after iteration 30500: 0.001657
# Cost after iteration 30600: 0.001651
# Cost after iteration 30700: 0.001646
# Cost after iteration 30800: 0.001640
# Cost after iteration 30900: 0.001635
# Cost after iteration 31000: 0.001630
# Cost after iteration 31100: 0.001624
# Cost after iteration 31200: 0.001619
# Cost after iteration 31300: 0.001614
# Cost after iteration 31400: 0.001609
# Cost after iteration 31500: 0.001604
# Cost after iteration 31600: 0.001599
# Cost after iteration 31700: 0.001594
# Cost after iteration 31800: 0.001589
# Cost after iteration 31900: 0.001584
# Cost after iteration 32000: 0.001579
# Cost after iteration 32100: 0.001575
# Cost after iteration 32200: 0.001570
# Cost after iteration 32300: 0.001565
# Cost after iteration 32400: 0.001560
# Cost after iteration 32500: 0.001556
# Cost after iteration 32600: 0.001551
# Cost after iteration 32700: 0.001547
# Cost after iteration 32800: 0.001542
# Cost after iteration 32900: 0.001537
# Cost after iteration 33000: 0.001533
# Cost after iteration 33100: 0.001529
# Cost after iteration 33200: 0.001524
# Cost after iteration 33300: 0.001520
# Cost after iteration 33400: 0.001515
# Cost after iteration 33500: 0.001511
# Cost after iteration 33600: 0.001507
# Cost after iteration 33700: 0.001503
# Cost after iteration 33800: 0.001498
# Cost after iteration 33900: 0.001494
# Cost after iteration 34000: 0.001490
# Cost after iteration 34100: 0.001486
# Cost after iteration 34200: 0.001482
# Cost after iteration 34300: 0.001478
# Cost after iteration 34400: 0.001474
# Cost after iteration 34500: 0.001470
# Cost after iteration 34600: 0.001466
# Cost after iteration 34700: 0.001462
# Cost after iteration 34800: 0.001458
# Cost after iteration 34900: 0.001455
# Cost after iteration 35000: 0.001451
# Cost after iteration 35100: 0.001447
# Cost after iteration 35200: 0.001443
# Cost after iteration 35300: 0.001440
# Cost after iteration 35400: 0.001436
# Cost after iteration 35500: 0.001432
# Cost after iteration 35600: 0.001429
# Cost after iteration 35700: 0.001425
# Cost after iteration 35800: 0.001422
# Cost after iteration 35900: 0.001418
# Cost after iteration 36000: 0.001415
# Cost after iteration 36100: 0.001411
# Cost after iteration 36200: 0.001408
# Cost after iteration 36300: 0.001404
# Cost after iteration 36400: 0.001401
# Cost after iteration 36500: 0.001398
# Cost after iteration 36600: 0.001394
# Cost after iteration 36700: 0.001391
# Cost after iteration 36800: 0.001388
# Cost after iteration 36900: 0.001384
# Cost after iteration 37000: 0.001381
# Cost after iteration 37100: 0.001378
# Cost after iteration 37200: 0.001375
# Cost after iteration 37300: 0.001372
# Cost after iteration 37400: 0.001369
# Cost after iteration 37500: 0.001366
# Cost after iteration 37600: 0.001363
# Cost after iteration 37700: 0.001360
# Cost after iteration 37800: 0.001357
# Cost after iteration 37900: 0.001354
# Cost after iteration 38000: 0.001351
# Cost after iteration 38100: 0.001348
# Cost after iteration 38200: 0.001345
# Cost after iteration 38300: 0.001343
# Cost after iteration 38400: 0.001340
# Cost after iteration 38500: 0.001337
# Cost after iteration 38600: 0.001334
# Cost after iteration 38700: 0.001332
# Cost after iteration 38800: 0.001329
# Cost after iteration 38900: 0.001327
# Cost after iteration 39000: 0.001324
# Cost after iteration 39100: 0.001321
# Cost after iteration 39200: 0.001319
# Cost after iteration 39300: 0.001316
# Cost after iteration 39400: 0.001314
# Cost after iteration 39500: 0.001311
# Cost after iteration 39600: 0.001309
# Cost after iteration 39700: 0.001306
# Cost after iteration 39800: 0.001304
# Cost after iteration 39900: 0.001301
# Cost after iteration 40000: 0.001299
# Cost after iteration 40100: 0.001296
# Cost after iteration 40200: 0.001294
# Cost after iteration 40300: 0.001292
# Cost after iteration 40400: 0.001289
# Cost after iteration 40500: 0.001287
# Cost after iteration 40600: 0.001285
# Cost after iteration 40700: 0.001282
# Cost after iteration 40800: 0.001280
# Cost after iteration 40900: 0.001278
# Cost after iteration 41000: 0.001276
# Cost after iteration 41100: 0.001273
# Cost after iteration 41200: 0.001271
# Cost after iteration 41300: 0.001269
# Cost after iteration 41400: 0.001267
# Cost after iteration 41500: 0.001265
# Cost after iteration 41600: 0.001262
# Cost after iteration 41700: 0.001260
# Cost after iteration 41800: 0.001258
# Cost after iteration 41900: 0.001256
# Cost after iteration 42000: 0.001254
# Cost after iteration 42100: 0.001252
# Cost after iteration 42200: 0.001250
# Cost after iteration 42300: 0.001248
# Cost after iteration 42400: 0.001246
# Cost after iteration 42500: 0.001244
# Cost after iteration 42600: 0.001241
# Cost after iteration 42700: 0.001239
# Cost after iteration 42800: 0.001237
# Cost after iteration 42900: 0.001235
# Cost after iteration 43000: 0.001233
# Cost after iteration 43100: 0.001232
# Cost after iteration 43200: 0.001230
# Cost after iteration 43300: 0.001228
# Cost after iteration 43400: 0.001226
# Cost after iteration 43500: 0.001224
# Cost after iteration 43600: 0.001222
# Cost after iteration 43700: 0.001221
# Cost after iteration 43800: 0.001219
# Cost after iteration 43900: 0.001217
# Cost after iteration 44000: 0.001216
# Cost after iteration 44100: 0.001214
# Cost after iteration 44200: 0.001212
# Cost after iteration 44300: 0.001211
# Cost after iteration 44400: 0.001209
# Cost after iteration 44500: 0.001208
# Cost after iteration 44600: 0.001206
# Cost after iteration 44700: 0.001205
# Cost after iteration 44800: 0.001203
# Cost after iteration 44900: 0.001202
# Cost after iteration 45000: 0.001200
# Cost after iteration 45100: 0.001199
# Cost after iteration 45200: 0.001197
# Cost after iteration 45300: 0.001196
# Cost after iteration 45400: 0.001194
# Cost after iteration 45500: 0.001193
# Cost after iteration 45600: 0.001191
# Cost after iteration 45700: 0.001190
# Cost after iteration 45800: 0.001189
# Cost after iteration 45900: 0.001187
# Cost after iteration 46000: 0.001186
# Cost after iteration 46100: 0.001184
# Cost after iteration 46200: 0.001183
# Cost after iteration 46300: 0.001182
# Cost after iteration 46400: 0.001180
# Cost after iteration 46500: 0.001179
# Cost after iteration 46600: 0.001177
# Cost after iteration 46700: 0.001176
# Cost after iteration 46800: 0.001175
# Cost after iteration 46900: 0.001173
# Cost after iteration 47000: 0.001172
# Cost after iteration 47100: 0.001171
# Cost after iteration 47200: 0.001169
# Cost after iteration 47300: 0.001168
# Cost after iteration 47400: 0.001167
# Cost after iteration 47500: 0.001166
# Cost after iteration 47600: 0.001164
# Cost after iteration 47700: 0.001163
# Cost after iteration 47800: 0.001162
# Cost after iteration 47900: 0.001161
# Cost after iteration 48000: 0.001159
# Cost after iteration 48100: 0.001158
# Cost after iteration 48200: 0.001157
# Cost after iteration 48300: 0.001156
# Cost after iteration 48400: 0.001155
# Cost after iteration 48500: 0.001153
# Cost after iteration 48600: 0.001152
# Cost after iteration 48700: 0.001151
# Cost after iteration 48800: 0.001150
# Cost after iteration 48900: 0.001149
# Cost after iteration 49000: 0.001148
# Cost after iteration 49100: 0.001147
# Cost after iteration 49200: 0.001145
# Cost after iteration 49300: 0.001144
# Cost after iteration 49400: 0.001143
# Cost after iteration 49500: 0.001142
# Cost after iteration 49600: 0.001141
# Cost after iteration 49700: 0.001140
# Cost after iteration 49800: 0.001139
# Cost after iteration 49900: 0.001138

# %%
pred_train = predict(mse_X_train, mse_Y_train, parameters, loss="mse")

p, caches = L_model_forward(mse_X_train, parameters)
print((p*100-mse_Y_train*100)[:,0:50])
# Out:
# Accuracy: 0.0002182866373288231
# [[ 0.88348918 -1.28021169  1.94962337  1.47097006 -1.98806419  1.46510591
#   -2.50165759 -1.02535782  1.20989068  0.52137     0.51766765  1.93253589
#    5.85276607  1.82057246  3.69128526  4.73793509 -0.64463364 -0.25648921
#   -2.06934393  1.19071955 -1.38815207  4.73805435  1.00066112  0.51890177
#    1.92705666  3.69552527  0.88409953 -4.51786279  0.52013589 -2.48170437
#   -2.52832672 -2.38813113 -0.38916149  7.15181171 -0.54833198 -2.49118602
#    2.05902671 -1.43692599  0.2641932   2.0620329   7.03583942  1.94626742
#   -5.84566622  1.09931328 -2.06558354  0.52322116 -2.49413973  0.26165148
#   -2.34723571  4.73733879]]

# %%
pred_test = predict(mse_X_test, mse_Y_test, parameters, loss="mse")

p, caches = L_model_forward(mse_X_test, parameters)

print((p*100-mse_Y_test*100)[:,0:50])
# Out:
# Accuracy: 0.00019096628644517025
# [[ 0.14027815 -0.385731   -1.43387708 -0.54919116 -2.06874221 -2.95191877
#    2.71804684 -8.13465196  2.05827514 -0.54403658 -2.34153983  7.03696448
#    0.52167853  7.21819985 -0.64463364  4.74067845  0.26131261 -1.04040506
#   -3.92703951 -1.43123442  1.21920636  1.74833836  1.95106155 -2.47674047
#   -3.2878032   1.94530852 -5.84566622  0.08148848  1.7484793   0.13810464
#   -2.22518837  0.99828149  5.8565243  -2.21889851 -2.95009517  0.88013222
#   -2.47301717 -0.9565661  -1.3841964  -0.64804583  2.0667923   0.51118841
#   -2.39340634 -2.12998615  4.73960489 -1.99597997  2.71998068  2.05156228
#    0.13127356  4.73745805]]
